# %% [markdown]
# #Theme Park Sentiment analysis and LDA Modeling
# By Ramandeep Kaur

# %% [markdown]
# ##Table of Content
#
# 1. Executive Summary
#
# 2. Data Exploration
# 3. Sentiment Analysis
# 4. Topic Modeling
# 5. Practical Implication

# %% [markdown]
# <a id = "cell_executivesummary"></a>
# # 1. Executive Summary

# %% [markdown]
# **Aim:** To clearly articulate the understanding of customer concerns and interests at theme parks, enabling management to enhance visitor satisfaction and optimize park services.
#
# The business problem is to identify and address the specific needs and preferences of theme park visitors from different locations. This project aims to analyze customer reviews to uncover themes and sentiment trends to improve park services, enhance visitor experiences, and drive higher attendance and revenue.
#
# We employed sentiment analysis and Latent Dirichlet Allocation (LDA) modeling to examine customer reviews. Sentiment analysis assessed overall sentiment towards park services, while LDA modeling identified primary topics of concern and interest. Additionally, we analyzed the top 10 visitor groups at each theme park branch and peak visiting times at the California branch.
#
# Our findings indicate that UK visitors focus on logistics, while US visitors prioritize overall experience and attractions. Visitor group analysis revealed geographical preferences, with California attracting Western visitors, Hong Kong drawing regional Asian tourists, and Paris seeing significant European visitors. Peak visiting times show domestic visitors peak in July and October, while international visitors peak in July and December. These insights, detailed in sections "Sentiment Analysis," "Topic Modeling," "Visitor Demographics," and "Peak Visiting Times," provide actionable information for targeted improvements in services, marketing strategies, and visitor engagement initiatives.

# %%
#Mounting google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#loading the NLTK toolbox
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from matplotlib import pyplot

# %% [markdown]
# ## 2. Data Exploration
#
# **Aim:** The aim of data exploration is to gain initial insights and understand patterns within the dataset to inform further analysis.

# %% [markdown]
# In this section, we imported the dataset containing reviews of different branches of a theme park into a pandas DataFrame. The dataset is read from a CSV file using the pd.read_csv() function. After loading the dataset, we use df.head() to preview the first five rows.
#
#
# This preview helps us understand the structure and contents of the dataset, which is essential for subsequent analysis, including sentiment analysis of the reviews.

# %%
#importing dataset
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ADV AI/ThemeParkReviews.csv')
df.head()
# Out:
#    Review_ID Year_Month Reviewer_Location  \
# 0  148524565    2012-12     United States
# 1  346403028     2015-3     United States
# 2  284580024     2015-6     United States
# 3  410306562    2015-12            Canada
# 4  358484811     2015-7     United States
#
#                                                                                                                                                                                                Review_Text  \
# 0  Loved seeing the Christmas lights at the park, but the crowds were the worst we had ever seen. We have been to Disneyland many times and have experienced long wait times in the past, but this visi...
# 1                                                                       I'm not sure reviewing Disneyland even has a point. Always a great day couple of days with the family. My kids love it, of course.
# 2  Went to Disneyland for one day. We arrive at opening and left at midnight. We loved all it had to offer. My kids are older so we did not spend time waiting in line to meet characters. Use the fast...
# 3  I travelled to Disneyland from Toronto in December 2015 for the very first time. It was EVERYthing that you can imagine. I've dreamed about that day since I was a little girl and was so happy I go...
# 4  This place might be ok for families with kids. My wife and I went to remember our past experiences when things were much less expensive. The park is packed with guests and hard to navigate. Prices...
#
#        Branch
# 0  California
# 1  California
# 2  California
# 3  California
# 4  California

# %% [markdown]
# ##Top 10 groups of visitors at each theme park branch according to their location of origin.
#
#
# The study evaluated and contrasted the leading 10 visitor demographics at each theme park location according to their place of origin.
#
#
# In California, the majority of visitors were from the United States, followed by Australia, Canada, and the United Kingdom, along with a variety of other nations including New Zealand, India, Mexico, Singapore, the Philippines, and Brazil.
#
#
# The Hong Kong branch attracted many visitors from Australia and India, in addition to guests from the Philippines, the United States, and neighboring Asian countries such as Singapore, Malaysia, and Indonesia.
#
#
# Paris experienced the highest visitor numbers from the United Kingdom, followed by the United States and Australia, with significant contributions from other European nations like Ireland, the Netherlands, France, Belgium, and Germany.
#
#
# The variations in visitor demographics are linked to factors such as geographical closeness, cultural connections, and travel trends in different regions. California tends to draw more tourists from Western nations, while Hong Kong sees a larger influx of regional visitors from Asia, and Paris attracts a considerable number of guests from European countries.

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Grouping by Branch and Reviewer_Location, and count the number of reviews
visitor_counts = df.groupby(['Branch', 'Reviewer_Location']).size().reset_index(name='Count')

# Sorting the counts in descending order
visitor_counts = visitor_counts.sort_values(by=['Branch', 'Count'], ascending=[True, False])

# the top 10 visitor locations for each branch
top_visitor_groups = visitor_counts.groupby('Branch').head(10)

# Displaying the top visitor groups
print(top_visitor_groups)

# Ploting the top visitor groups for each branch
branches = top_visitor_groups['Branch'].unique()

fig, axes = plt.subplots(nrows=len(branches), ncols=1, figsize=(12, len(branches) * 5))

for i, branch in enumerate(branches):
    ax = axes[i]
    data = top_visitor_groups[top_visitor_groups['Branch'] == branch]
    ax.barh(data['Reviewer_Location'], data['Count'], color='skyblue')
    ax.set_title(f'Top 10 Visitor Locations for {branch}')
    ax.set_xlabel('Number of Visitors')
    ax.set_ylabel('Location of Origin')

plt.tight_layout()
plt.show()
# Out:
#          Branch     Reviewer_Location  Count
# 100  California         United States  10152
# 2    California             Australia   2010
# 11   California                Canada   1511
# 99   California        United Kingdom    852
# 61   California           New Zealand    423
# 38   California                 India    111
# 57   California                Mexico     86
# 79   California             Singapore     78
# 70   California           Philippines     45
# 8    California                Brazil     44
# 106    HongKong             Australia   1358
# 145    HongKong                 India    887
# 180    HongKong           Philippines    811
# 211    HongKong         United States    723
# 191    HongKong             Singapore    687
# 210    HongKong        United Kingdom    606
# 143    HongKong             Hong Kong    429
# 162    HongKong              Malaysia    429
# 146    HongKong             Indonesia    374
# 209    HongKong  United Arab Emirates    173
# 333       Paris        United Kingdom   6574
# 334       Paris         United States   1078
# 224       Paris             Australia    496
# 268       Paris               Ireland    344
# 265       Paris                 India    246
# 237       Paris                Canada    154
# 297       Paris           Netherlands    150
# 253       Paris                France    148
# 230       Paris               Belgium    112
# 255       Paris               Germany    105

# %% [markdown]
# ##Comparing the peak visiting times at the California branch for domestic and international visitors.
#
# Domestic visitors peak in July (993) and October (905), driven by summer vacations and holiday periods. High numbers are also seen in June (966) and December (833). International visitors peak in July (523) with rising numbers in August and September, indicating summer travel preferences. Another smaller peak for international visitors occurs in December (531), aligning with the holiday season.
#
# Conclusion:
# Both visitor types peak in July, but domestic visitors have an additional peak in October due to local holiday patterns. International visitor patterns align with global summer travel trends and holiday seasons. These differences highlight the influence of local versus global travel behaviors on theme park visitation.

# %%
# Filter for the California branch
california_df = df[df['Branch'] == 'California'].copy()

# Defining domestic and international visitors
domestic_countries = ['United States']  # Define other domestic countries if applicable
california_df.loc[:, 'Visitor_Type'] = california_df['Reviewer_Location'].apply(lambda x: 'Domestic' if x in domestic_countries else 'International')

# Handling missing or invalid date values in the Year_Month column
california_df['Year_Month'] = california_df['Year_Month'].apply(lambda x: pd.NaT if x == 'missing' else x)

# Extract the month from the Year_Month column
california_df['Month'] = pd.to_datetime(california_df['Year_Month'], errors='coerce').dt.month

# Grouping by month and visitor type, and count the number of reviews
monthly_visits = california_df.groupby(['Month', 'Visitor_Type']).size().reset_index(name='Count')

# Pivot the table for easier plotting
pivot_table = monthly_visits.pivot(index='Month', columns='Visitor_Type', values='Count').fillna(0)

# Plotting the peak visiting times
fig, ax = plt.subplots(figsize=(12, 6))

pivot_table.plot(kind='bar', ax=ax)

ax.set_title('Peak Visiting Times at California Branch')
ax.set_xlabel('Month')
ax.set_ylabel('Number of Visitors')
ax.legend(title='Visitor Type')
ax.set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=0)

plt.tight_layout()
plt.show()

# Display the processed data
print(pivot_table)
# Out:
# Visitor_Type  Domestic  International
# Month
# 1.0                601            386
# 2.0                610            309
# 3.0                826            350
# 4.0                786            447
# 5.0                805            458
# 6.0                966            402
# 7.0                993            523
# 8.0                791            597
# 9.0                706            593
# 10.0               905            564
# 11.0               609            364
# 12.0               833            531

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option("display.max_colwidth", 200)

# %% [markdown]
# ##Data Cleaning
# We performed data cleaning on the review texts by removing non-alphabetic characters, converting text to lowercase, tokenizing, and stemming words using the PorterStemmer. Short words were removed to retain meaningful content, resulting in cleaned and standardized review texts for analysis.

# %%
from nltk.stem import PorterStemmer #Stemming Package
import re  #Regular expression operation package

porter = PorterStemmer()

documents = df['Review_Text']
Cleaned_doc = []
for r in range(len(documents)):
    review = documents[r]
    try:
        # Noise Removal - removing everything except alphabets
        review = re.sub('[^A-Za-z]', ' ', review)
        # make all text lowercase
        review = review.lower()
        # applying tokenization
        Tokens = review.split()
        # applying stemming operation
        for t in range(len(Tokens)):
            Tokens[t] = porter.stem(Tokens[t])
        # removing short words
        Filtered_token = [w for w in Tokens if len(w)>3]
        review = ' '.join(Filtered_token)
    except:
        continue
    #Save cleaned text
    Cleaned_doc.append(review)
    print('-[Review Text]: ', review)
# Out:
# Streaming output truncated to the last 5000 lines.
# -[Review Text]:  book trip daughter myself disneyland pari could have break from stress famili bereav last time visit around year when park quit memori pretti magic sinc then have gone california park mani time alway enjoy with fairli high expect that head weekend first thing notic that clientel vastli differ from befor there were mani perfectli nice famili group from franc germani netherland seem park attract life type roam park mostli roma type their from eastern europ would question their purpos there they certainli weren there ride spot them their uniform shini puffa bomber jacket jean trainer strong cigarett smoke park usual ride fantasyland small world good probabl better than carousel snow white pinocchio were fine peter technic problem couldn head adventureland were realli disappoint that pirat caribbean close that main attract want mention anywher befor into park howev haunt mansion excel with great detail chocol cooki morn cabl bake shop euro which heat bite cold never underestim cold here bitter realli chill through later some chalet marionett cafe where individu item instead full menu difficult usual veri much burger nugget which doesn work well have vegetarian your group healthi wasn featur later realis that peter oper again join long queue bitterli cold then left daughter wait ride head coffe back cabl bake shop awar that stand right against close queue paid drink down tabl open check everyth cours purs been stolen with card cash gone puffa jacket dodgi eastern european queue even citi hall report loss with snowbal chanc hell anyth back sadli magic gone along with purs which find myself airport penniless with have sandwich
# -[Cleaned Text]:  massiv disney visit disneyland pari past veri good experi book weekend trip partner experi disney enchant christma christma theme love frozen work show parad christma parad veri festiv littl shorter expect mickey wreath christma light everywher gave love atmospher park gener look shabbi area could fresh paint custom servic good america either mani staff seem quit harri number rude unfriendli said coupl member staff went extra friendli inform visit weekend park especi busi point close gate peopl book ticket limit number meant queue time much longer experienc previou visit fast track alloc fairli quickli would still recommend visit like disney park someth magic definit worth book midweek mean quieter park notic shorter queue time
# -[Cleaned Text]:  theme park mainten problem crowd wait long time attract special ticket rich snob first alway wait hour littl attract maintain anoth nice thing notic wait hour
# -[Cleaned Text]:  disney orlando california pari team somewhat ride slow process ride rush shorten shortag charact walk around realli need bring game bear price paid need deliv fast food outlet poor poor poor restaur full tabl servic choic improv qualiti side love ride ride

# %% [markdown]
# # 3. Sentiment Analysis
# Aim: The aim of the sentiment analysis is to evaluate and compare customer satisfaction levels regarding the services provided by theme park branches in California, Hong Kong, and Paris. By analyzing aspect-specific sentiments, we aim to identify which branch receives the most positive feedback for its services.
#
#
# Sentiment analysis is the computational process of finding and categorizing the emotional tone expressed in a piece of text.

# %% [markdown]
# Lexicon based Sentiment analysis

# %%
# first, we import the relevant modules from the NLTK library
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
#Initialize an instance of SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

message_text = df['Review_Text'][1]
print('Review Comment:\n', message_text)
# Out:
# Review Comment:
#  I'm not sure reviewing Disneyland even has a point. Always a great day couple of days with the family. My kids love it, of course.

# %%
#Estimate sentiment scores
scores = sid.polarity_scores(message_text)
for key in sorted(scores):
        print('{0}: {1} \n'.format(key, scores[key]), end='')
print('True Recommedation Label was: ', df['Review_Text'][1])
# Out:
# compound: 0.8094
# neg: 0.065
# neu: 0.661
# pos: 0.274
# True Recommedation Label was:  I'm not sure reviewing Disneyland even has a point. Always a great day couple of days with the family. My kids love it, of course.

# %% [markdown]
# We performed sentiment analysis using a lexicon-based approach. Sentiment scores were calculated as follows: compound score: 0.8094, negative score: 0.065, neutral score: 0.661, and positive score: 0.274. This allowed us to quantify the sentiment expressed in the review texts.

# %%
#Compute Sentiment Score by text trunk
from nltk.tokenize import sent_tokenize
import nltk
nltk.download('punkt')

ReviewComment=ReviewComment.replace(',','.')
sents =  sent_tokenize(ReviewComment)
scores = []
for s in range(len(sents)):
       scores.append(sid.polarity_scores(sents[s]))
[s for s in scores] #Show sentiment score of individual trunks
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [{'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.184, 'neu': 0.816, 'pos': 0.0, 'compound': -0.2023},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.434, 'neu': 0.566, 'pos': 0.0, 'compound': -0.7845},
#  {'neg': 0.0, 'neu': 0.842, 'pos': 0.158, 'compound': 0.4939},
#  {'neg': 0.147, 'neu': 0.736, 'pos': 0.117, 'compound': -0.1779},
#  {'neg': 0.38, 'neu': 0.62, 'pos': 0.0, 'compound': -0.5994},
#  {'neg': 0.0, 'neu': 0.626, 'pos': 0.374, 'compound': 0.3382},
#  {'neg': 0.155, 'neu': 0.845, 'pos': 0.0, 'compound': -0.296},
#  {'neg': 0.0, 'neu': 0.692, 'pos': 0.308, 'compound': 0.5346},
#  {'neg': 0.329, 'neu': 0.671, 'pos': 0.0, 'compound': -0.5994},
#  {'neg': 0.151, 'neu': 0.757, 'pos': 0.092, 'compound': -0.2244},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0},
#  {'neg': 0.421, 'neu': 0.579, 'pos': 0.0, 'compound': -0.6249},
#  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}]

# %% [markdown]
# ## Overall sentiments for each branch and evaluating the branch with the most positive sentiments

# %%
# Calculate average sentiment for each branch
branch_sentiments = {}
for branch in df['Branch'].unique():
    branch_reviews = df[df['Branch'] == branch]['Review_Text']
    compound_scores = []
    for review in branch_reviews:
        scores = sid.polarity_scores(review)
        compound_scores.append(scores['compound'])

    average_sentiment = sum(compound_scores) / len(compound_scores)
    branch_sentiments[branch] = average_sentiment

# Find the branch with the most positive sentiment
most_positive_branch = max(branch_sentiments, key=branch_sentiments.get)

print("Average Sentiments for Each Branch:")
for branch, sentiment in branch_sentiments.items():
    print(f"{branch}: {sentiment}")

print(f"\nThe theme park with the most positive sentiments is: {most_positive_branch}")
# Out:
# Average Sentiments for Each Branch:
# California: 0.6957583970422341
# HongKong: 0.7075664087276419
# Paris: 0.6433898019535766
#
# The theme park with the most positive sentiments is: HongKong

# %% [markdown]
# ##Theme park branch that received the most positive sentiment for their “services” - Aspect sentiment analysis

# %% [markdown]
# We performed a sentiment analysis to compare customer sentiments across different theme park branches using lexicon-based analysis. Each review's compound sentiment score was calculated and averaged for each branch. The results indicate the following average sentiment scores: California (0.696), HongKong (0.708), and Paris (0.643). HongKong received the most positive sentiments, with an average score of 0.708. This higher score may be due to exceptional customer experiences, superior service quality, or unique attractions at the HongKong branch, leading to more positive reviews. The analysis highlights the importance of customer satisfaction in maintaining positive sentiment.

# %% [markdown]
# We performed aspect sentiment analysis on reviews for theme park branches to evaluate the sentiment related to their services.

# %%
#Defining a function to compute overall sentiment by aspect
def aspect_sentiment(aspect,reviewtext):
    SentimentIndex = []

    # For each review in the data set
    for rev in (reviewtext):
        try:
            sens =  sent_tokenize(rev)
        except:
            continue
        #Compute sentiment scores by each sentence.
        ReviewLevelSentiment = []
        for s in range(len(sens)):
            IndexAspect = sens[s].find(aspect)
            if IndexAspect > 0:
                ReviewLevelSentiment.append(sid.polarity_scores(sens[s]))

        #Aggregating sentiment scores for each review
        try:
            Compound = mean([ReviewLevelSentiment[x]['compound'] for x in range(len(ReviewLevelSentiment))])
        except:
            Compound = 0

        # Generating sentiment index based on sentiment score
        SentimentIndex.append(Compound)

         # Define thresholds
        positive_threshold = 0.1
        negative_threshold = -0.1

        # Initialize counters
        positive_count = 0
        negative_count = 0

        for value in SentimentIndex:
            if value > positive_threshold:
                positive_count += 1
            elif value < negative_threshold:
                negative_count += 1
        Total_Count = positive_count + negative_count
    return [round(positive_count/Total_Count,2), round(negative_count/Total_Count,2)]

# %%
#Defining Aspects to compute sentiment
aspects = ['services']

#Extracting Reviews for Californias only and compute aspect sentiments
print('Sentiment scores for California:')
CaliforniaReviews = df.loc[df['Branch'] == 'California']
SentimentScoresCalifornia = []
for a in range(len(aspects)):
    SentimentScoresCalifornia.append(aspect_sentiment(aspects[a],CaliforniaReviews['Review_Text']))
    print(aspects[a])
    print(SentimentScoresCalifornia[a])

print('--------------------------------')
#Extracting Reviews for HongKong only and compute aspect sentiments
print('Sentiment scores for HongKong:')
HongKongReviews = df.loc[df['Branch'] == 'HongKong']
SentimentScoresHongKong = []
for a in range(len(aspects)):
    SentimentScoresHongKong.append(aspect_sentiment(aspects[a],HongKongReviews['Review_Text']))
    print(aspects[a])
    print(SentimentScoresHongKong[a])

print('--------------------------------')
#Extracting Reviews for Paris only and compute aspect sentiments
print('Sentiment scores for Paris:')
ParisReviews = df.loc[df['Branch'] == 'Paris']
SentimentScoresParis = []
for a in range(len(aspects)):
    SentimentScoresParis.append(aspect_sentiment(aspects[a],ParisReviews['Review_Text']))
    print(aspects[a])
    print(SentimentScoresParis[a])
# Out:
# Sentiment scores for California:
# services
# [0.79, 0.21]
# --------------------------------
# Sentiment scores for HongKong:
# services
# [0.75, 0.25]
# --------------------------------
# Sentiment scores for Paris:
# services
# [0.7, 0.3]

# %% [markdown]
# Based on the sentiment analysis of reviews for theme park branches in California, Hong Kong, and Paris, it is evident that the California branch received the most positive sentiment regarding their services. The sentiment scores are as follows: California scored 0.79 in positive sentiment, Hong Kong scored 0.75, and Paris scored 0.7. This analysis indicates that visitors to the California branch were the most satisfied with the services provided. The higher positive sentiment score for California suggests that its services are perceived as superior compared to the other branches. Therefore, California stands out as the branch with the most favorable service reviews among the three locations. Furthermore, we have bar chart to present the same

# %%
#Plotting the Positive sentiment scores on a bar chart
import numpy
from matplotlib import pyplot

PositiveCalifornia = [SentimentScoresCalifornia[x][0] for x in range(len(SentimentScoresCalifornia))]
PositiveHongKong = [SentimentScoresHongKong[x][0] for x in range(len(SentimentScoresHongKong))]
PositiveParis = [SentimentScoresParis[x][0] for x in range(len(SentimentScoresParis))]

aspects = ['Services']

ind = numpy.arange(len(aspects))  # the x locations for the groups
width = 0.27       # the width of the bars

# Plot figure for positive reviews
figPo = pyplot.figure(figsize=(6, 4))
ax = figPo.add_subplot(111)

rectsPositiveCalifornia = ax.bar(ind, PositiveCalifornia, width, color='b')
rectsPositiveHongKong = ax.bar(ind+width, PositiveHongKong, width, color='g')
rectsPositiveParis = ax.bar(ind+2*width, PositiveParis, width, color='r')

ax.set_ylabel('Proportion')
ax.set_xticks(ind + width)
ax.set_xticklabels(aspects)
ax.legend((rectsPositiveCalifornia[0], rectsPositiveHongKong[0], rectsPositiveParis[0]), ('California', 'HongKong', 'Paris'), loc='lower center')
pyplot.suptitle('Positive Sentiment')
# Out:
# Text(0.5, 0.98, 'Positive Sentiment')

# %% [markdown]
# # 4. Topic Modeling - Latent Dirichlet Allocation
# **Aim** : The aim of LDA modeling is to uncover hidden thematic structures in the review data by identifying distinct topics and their distributions. This helps in understanding the primary concerns and interests of customers visiting the theme parks.

# %% [markdown]
# Latent Dirichlet Allocation (LDA) is a generative statistical model used to identify and categorize topics within a collection of documents based on word distributions.
#
# To build the LDA model, we started by processing the review texts, extracting the 40 most common words to identify frequent terms. Using the code provided, we visualized these words and their counts. Recognizing that words like "park," "ride," and "disneyland" were overly common and non-informative for topic discovery, we implemented term selection. This involved extracting nouns and filtering out both highly frequent and infrequent terms. As a result, we retained 1688 relevant terms. This preprocessing step ensured that the LDA model would effectively identify meaningful topics from the review data, enhancing our analysis of customer feedback.

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vectorizer = CountVectorizer()# Fit and transform the processed titles

count_data = count_vectorizer.fit_transform(Cleaned_doc)
count_data
# Out:
# <35000x22878 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1551294 stored elements in Compressed Sparse Row format>

# %%
terms = count_vectorizer.get_feature_names_out()

# Count the popularity of words
total_counts = np.zeros(len(terms))
for t in count_data:
    total_counts+=t.toarray()[0]

count_dict = (zip(terms, total_counts))
count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:40] #Take the top 40 words

words = [w[0] for w in count_dict]
counts = [w[1] for w in count_dict]
x_pos = np.arange(len(words))

plt.figure(2, figsize=(11, 3))
plt.subplot(title='40 most common words')
plt.bar(words, counts)
plt.xticks(x_pos, words, rotation=90)
plt.xlabel('words')
plt.ylabel('counts')
plt.show()

# %% [markdown]
# ##Term Selection
#
# Highly frequent words like "park," "ride," and "disneyland" do not aid in topic discovery since they are common in most reviews. These overly frequent words should be discarded. Additionally, infrequent words that appear only a few times in the entire dataset should also be removed, as they offer little value.

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# Function to extract nouns from text
def extract_nouns(text):
    words = word_tokenize(text)
    words_pos = pos_tag(words)
    nouns = [word for word, pos in words_pos if pos.startswith('NN')]
    return ' '.join(nouns)

# Apply the function to the review text1
df['Nouns_Only'] = df['Review_Text'].apply(extract_nouns)

# Display the first few rows to ensure the nouns extraction is correct
df[['Review_Text', 'Nouns_Only']].head()
# Out:
#                                                                                                                                                                                                Review_Text  \
# 0  Loved seeing the Christmas lights at the park, but the crowds were the worst we had ever seen. We have been to Disneyland many times and have experienced long wait times in the past, but this visi...
# 1                                                                       I'm not sure reviewing Disneyland even has a point. Always a great day couple of days with the family. My kids love it, of course.
# 2  Went to Disneyland for one day. We arrive at opening and left at midnight. We loved all it had to offer. My kids are older so we did not spend time waiting in line to meet characters. Use the fast...
# 3  I travelled to Disneyland from Toronto in December 2015 for the very first time. It was EVERYthing that you can imagine. I've dreamed about that day since I was a little girl and was so happy I go...
# 4  This place might be ok for families with kids. My wife and I went to remember our past experiences when things were much less expensive. The park is packed with guests and hard to navigate. Prices...
#
#                                                                                                                                                                                                 Nouns_Only
# 0                                   Christmas lights park crowds Disneyland times times visit crowds crowds people parking wheel chairs entry park people time people lights decorations Christmas holiday
# 1                                                                                                                                                      Disneyland point day couple days family kids course
# 2                                                        Went Disneyland day opening midnight kids time line characters passes day reason parks Day way day night activities fireworks parade magic Disney
# 3  Disneyland Toronto December time day girl Birthday boyfriend reservations Birthday Dinner Goofy Kitchen dinner buffet food Disney characters fun laughter characters juts photos guests.The rides Di...
# 4                                                    place families kids wife experiences things park guests Prices food parking entrance fees value kids experience bit attractions repair advance notice

# %%
# Vectorize the noun-only text data
vectorizer = CountVectorizer(stop_words='english')
data_vectorized = vectorizer.fit_transform(df['Nouns_Only'])

# Get the total counts of words
total_counts = np.asarray(data_vectorized.sum(axis=0)).flatten()
terms = vectorizer.get_feature_names_out()

# %%
#Removing highly frequent (Greater than 20%) and infrequent words (less than 1%)
keepIndex = [];
for t in range(len(total_counts)):
    if total_counts[t] < 1000 and total_counts[t] > 50:
        keepIndex.append(t)

print('Number of Terms Remained: ', len(keepIndex))

#Save the remain ing term and frequency data
ReducedTerm = [terms[t] for t in keepIndex]
ReducedCount = data_vectorized[:,keepIndex]
ReducedCount
# Out:
# Number of Terms Remained:  1688
# <35000x1688 sparse matrix of type '<class 'numpy.int64'>'
# 	with 318983 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ##LDA Modeling

# %% [markdown]
# ##Experiment with Topic Numbers
# Constructing multiple LDA modles with varied numbers of topics and evaluate their coherence score.

# %%
#Evaluation models with topics numbers from 2 to 10
Topics = list(range(2,11,1))
coherence_scores = []
Trained_Models = []
for top in Topics:
    lda_model = gensim.models.ldamodel.LdaModel(corpus=Corpus,
                                               id2word=id2word,
                                               num_topics=top,
                                               random_state=100)
    #Keeping the trained models
    Trained_Models.append(lda_model)
    #Computing coherence score for each model
    coherence_model_lda = CoherenceModel(model=lda_model,
                                         texts=Cleaned_doc_new,
                                         dictionary=id2word,
                                         coherence='c_v')
    coherence = coherence_model_lda.get_coherence()
    #Save and print the coherence scores
    coherence_scores.append(coherence)
    print('Topic Number: {0} -- Coherence: {1}'.format(top, coherence))
# Out:
# Topic Number: 2 -- Coherence: 0.7248823689270462
# Topic Number: 3 -- Coherence: 0.7144007809946992
# Topic Number: 4 -- Coherence: 0.7135729250767753
# Topic Number: 5 -- Coherence: 0.7189570988298731
# Topic Number: 6 -- Coherence: 0.7132335046614467
# Topic Number: 7 -- Coherence: 0.7244440252522415
# Topic Number: 8 -- Coherence: 0.7204545731301549
# Topic Number: 9 -- Coherence: 0.704844249404617
# Topic Number: 10 -- Coherence: 0.7121500287774262

# %% [markdown]
# We experimented with LDA models, evaluating coherence scores for 2 to 10 topics. With the second-highest coherence score of 0.7244, 7 topics were selected as optimal, balancing coherence and interpretability, whereas 2 topics were too few to provide meaningful insights.

# %% [markdown]
# #Number of topics - 7
# Chosing the most ideal topic numbers as 7 and training a model on that

# %% [markdown]
# ##What are the concerns or interests of customers when visiting the theme parks?

# %%
from sklearn.decomposition import LatentDirichletAllocation as LDA

# Tweak the two parameters below
number_topics = 7

lda = LDA(n_components=number_topics, n_jobs=-1, random_state=2023)
lda.fit(ReducedCount)
#Trained LDA model
lda.components_
# Out:
# array([[ 0.1431428 , 10.78422627,  0.15050818, ..., 74.92972112,
#          6.81601905,  0.14302401],
#        [ 1.05400619, 23.83496371,  3.70231146, ...,  0.14329842,
#          0.1430794 ,  1.3160524 ],
#        [ 5.23857765,  0.14332655, 14.63528622, ..., 34.80090111,
#         32.95144348,  0.14294942],
#        ...,
#        [17.87727307, 46.34702555,  0.16534878, ...,  5.65845188,
#          8.04695834,  0.23245483],
#        [10.16683135, 20.60398727, 21.87300069, ..., 15.12100216,
#         15.76088941,  0.14327062],
#        [33.45411768,  0.1432852 , 37.33048567, ..., 25.35988664,
#          0.59115918, 58.50238846]])

# %% [markdown]
# ###Word Probabilities by Topic

# %%
#Word Probablities in Topics
Word_Topics_Pro = lda.components_ / lda.components_.sum(axis=1)[:, np.newaxis]
print(Word_Topics_Pro)
# Out:
# [[2.35466272e-06 1.77397788e-04 2.47582135e-06 ... 1.23257491e-03
#   1.12121785e-04 2.35270873e-06]
#  [3.05611201e-05 6.91099536e-04 1.07349261e-04 ... 4.15496639e-06
#   4.14861577e-06 3.81592024e-05]
#  [1.06032916e-04 2.90104163e-06 2.96229660e-04 ... 7.04397504e-04
#   6.66963033e-04 2.89340818e-06]
#  ...
#  [3.30486667e-04 8.56790291e-04 3.05670598e-06 ... 1.04604483e-04
#   1.48759401e-04 4.29725609e-06]
#  [1.88202852e-04 3.81409806e-04 4.04901092e-04 ... 2.79911768e-04
#   2.91757013e-04 2.65214783e-06]
#  [6.66803417e-04 2.85594317e-06 7.44066714e-04 ... 5.05470185e-04
#   1.17829132e-05 1.16606251e-03]]

# %% [markdown]
# These were the words that we obtained in each topic:

# %%
for topic_idx, topic in enumerate(Word_Topics_Pro):
    print("\nTopic #%d:" % topic_idx)
    count_dict = (zip(ReducedTerm, topic))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:5]
    for w in count_dict:
        print(w[0], ': {0:.3f}'.format(w[1]))
# Out:
# Topic #0:
# bus : 0.013
# tower : 0.011
# meet : 0.009
# terror : 0.009
# dreams : 0.009
#
# Topic #1:
# new : 0.026
# wdw : 0.021
# atmosphere : 0.019
# dream : 0.018
# ca : 0.016
#
# Topic #2:
# mtr : 0.017
# lion : 0.016
# king : 0.016
# grizzly : 0.013
# toy : 0.013
#
# Topic #3:
# school : 0.014
# holidays : 0.013
# la : 0.011
# hopper : 0.010
# advantage : 0.008
#
# Topic #4:
# customer : 0.013
# member : 0.012
# memories : 0.011
# friends : 0.011
# parents : 0.009
#
# Topic #5:
# ice : 0.011
# entry : 0.011
# car : 0.009
# security : 0.009
# meals : 0.009
#
# Topic #6:
# splash : 0.017
# matterhorn : 0.014
# haunted : 0.014
# party : 0.014
# tours : 0.014

# %%
# View full Word Probabilities by Topic Matrix
df_topic_keywords = pd.DataFrame(Word_Topics_Pro)
df_topic_keywords.columns = ReducedTerm
df_topic_keywords
# Out:
#     ability  absolute   academy    access  accommodation   account       act  \
# 0  0.000002  0.000177  0.000002  0.002121       0.001630  0.000074  0.000002
# 1  0.000031  0.000691  0.000107  0.000993       0.000004  0.000004  0.000117
# 2  0.000106  0.000003  0.000296  0.001536       0.000003  0.000003  0.000003
# 3  0.000583  0.000003  0.000003  0.003559       0.000073  0.000344  0.000003
# 4  0.000330  0.000857  0.000003  0.001289       0.000003  0.000279  0.000603
# 5  0.000188  0.000381  0.000405  0.003297       0.000268  0.000341  0.000315
# 6  0.000667  0.000003  0.000744  0.003739       0.000005  0.000060  0.000158
#
#      action  activities  activity  ...       yes  yesterday        yo  \
# 0  0.000801    0.000002  0.000002  ...  0.001199   0.000003  0.000041
# 1  0.000188    0.010102  0.001177  ...  0.000519   0.000372  0.000408
# 2  0.000267    0.001329  0.000600  ...  0.000132   0.000111  0.000712
# 3  0.000142    0.000018  0.000003  ...  0.000463   0.000003  0.000055
# 4  0.000936    0.000010  0.000074  ...  0.000638   0.001739  0.000003
# 5  0.001235    0.000021  0.000474  ...  0.000122   0.000045  0.000005
# 6  0.000339    0.000003  0.000316  ...  0.000034   0.000018  0.000339
#
#        york     young        yr       yrs      zone     zones       zoo
# 0  0.000575  0.000002  0.000752  0.000616  0.001233  0.000112  0.000002
# 1  0.004986  0.000986  0.000760  0.000109  0.000004  0.000004  0.000038
# 2  0.000003  0.000003  0.000130  0.000509  0.000704  0.000667  0.000003
# 3  0.000003  0.000084  0.001113  0.000747  0.000019  0.000207  0.000146
# 4  0.000003  0.000230  0.000458  0.000484  0.000105  0.000149  0.000004
# 5  0.000342  0.000014  0.000678  0.000199  0.000280  0.000292  0.000003
# 6  0.000003  0.000003  0.000297  0.000003  0.000505  0.000012  0.001166
#
# [7 rows x 1688 columns]

# %% [markdown]
# ###Visualize the word clouds for the topics generated by LDA

# %%
# !pip install wordcloud
from wordcloud import WordCloud
import math
import matplotlib.pyplot as pyplot

rows = math.ceil(len(Word_Topics_Pro)/4)
fig, ax = pyplot.subplots(rows, 4, figsize=(15,2.5*rows))

# Handle the case of a single row of subplots
if rows == 1:
    ax = ax.ravel()  # Flatten the array when there's only one row
else:
    ax = ax.ravel()  # Flatten the array for multiple rows

[axi.set_axis_off() for axi in ax]  # Turn off axes for all subplots

for topic_idx, topic in enumerate(Word_Topics_Pro):
    count_dict = (zip(ReducedTerm, topic))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)
    # convert to dictionary type - keep top 10 words
    Word_Frequency = dict(count_dict[0:10])
    # generate word cloud
    wordcloud = WordCloud(background_color="white").generate_from_frequencies(Word_Frequency)
    # visualize word cloud in figure
    subfig_idx = topic_idx  # Use a single index for 1D array
    ax[subfig_idx].imshow(wordcloud)  # Index as a 1D array
    ax[subfig_idx].set_title("Topic {}".format(topic_idx+1))
plt.show()
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# After performing topic modeling, the word clouds generated for each topic reveal the primary concerns and interests of customers when visiting the theme parks. Here are the insights from each topic:
#
# **Topic 1:** Concerns related to "tower," "bus," and "meet" suggest logistical aspects such as transportation and gathering points.
#
#
# **Topic 2:** Keywords like "new," "atmosphere," and "dream" indicate a focus on the overall experience and ambiance.
#
#
# **Topic 3**: The presence of "king," "lion," and "mountain" reflects interests in specific attractions and themed areas.
#
#
# **Topic 4:** Words such as "school," "holidays," and "families" highlight the timing of visits and family-oriented activities.
#
#
# **Topic 5:** Terms like "visitors," "problem," and "member" suggest concerns about membership benefits and potential issues faced by visitors.
#
#
# **Topic 6:** Keywords "car," "ice," and "entry" indicate practical concerns about parking, refreshments, and park entry.
#
#
# **Topic 7:** Words like "haunted," "party," and "splash" point to interests in specific events and water attractions.
#
#
# **These topics provide a comprehensive understanding of what customers care about most during their visits to the theme parks.**

# %% [markdown]
# Computer the popularity of topics over the entire data set to identify the most popular topics.

# %%
#Compute topic distribution for each document
TopicDis_Doc = lda.transform(ReducedCount)

#Compute overall topic distribution for all each documents
Overall_Topic_Dis = sum(TopicDis_Doc)/sum(sum(TopicDis_Doc))
Overall_Topic_Dis
# Out:
# array([0.13371476, 0.13188273, 0.13847388, 0.17305702, 0.16924643,
#        0.12078849, 0.13283669])

# %% [markdown]
# Visualize the topic distribution using bar chart

# %%
# Get the topic index
Bar_index = np.asarray(range(1,number_topics+1))

#Visualize topic distributions of review groups
pyplot.figure(figsize=(7,4))
pyplot.title('Topic Popularity', fontsize=16)
pyplot.xlabel('Topic')
pyplot.ylabel('Probability')
pyplot.bar(Bar_index, Overall_Topic_Dis.tolist(), 0.3)
pyplot.xticks(Bar_index, Bar_index)
pyplot.legend()
pyplot.show();
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Additionally, Topic 4 emerged as the most popular, indicating that timing and family activities are top priorities for visitors. The popularity distribution of topics underscores the varied aspects of customer experiences and priorities.

# %% [markdown]
# ###  Topic Probabilities by Document
#
# Compute the topic distribution for individual documents:

# %%
# View full Topic Probabilities by Document Matrix
TopicDis_Doc = lda.transform(ReducedCount)
df_document_topics = pd.DataFrame(TopicDis_Doc)
df_document_topics
# Out:
#               0         1         2         3         4         5         6
# 0      0.017908  0.017935  0.017937  0.017929  0.017908  0.018063  0.892321
# 1      0.142857  0.142857  0.142857  0.142857  0.142857  0.142857  0.142857
# 2      0.023845  0.422756  0.023861  0.457870  0.023909  0.023866  0.023893
# 3      0.106053  0.619762  0.253693  0.005128  0.005121  0.005121  0.005121
# 4      0.014316  0.014309  0.014298  0.640594  0.287783  0.014357  0.014344
# ...         ...       ...       ...       ...       ...       ...       ...
# 34995  0.017935  0.017887  0.017915  0.017907  0.162658  0.017925  0.747771
# 34996  0.020600  0.020534  0.020461  0.020517  0.876998  0.020420  0.020469
# 34997  0.294268  0.267556  0.007975  0.007965  0.406313  0.007952  0.007970
# 34998  0.047775  0.047639  0.047635  0.047663  0.047836  0.047699  0.713753
# 34999  0.028657  0.028599  0.028604  0.028627  0.341832  0.515083  0.028598
#
# [35000 rows x 7 columns]

# %%
# Compute the topic distribution for some reviews:
TopicDis_Doc = TopicDis_Doc[0:5]
print('Topic Probablity distribution by Document: \n', TopicDis_Doc)
# Get the topic index
Bar_index = np.asarray(range(1,number_topics+1))

#Create a new figure
pyplot.figure(figsize=(7,4))
pyplot.title('Topic Probability Distribution by Document', fontsize=16)
pyplot.xlabel('Topic')
pyplot.ylabel('Probability')

width = 0.15
for i in range(0,5):
    pyplot.bar(Bar_index + i*width, TopicDis_Doc[i].tolist(), width,  label='doc ' + str(i))

pyplot.xticks(Bar_index + 2*width, Bar_index)
pyplot.legend()
pyplot.show();
#NOTE: Different Run may result in Different Graph
#due to the Randomization when training the LDA model
# Out:
# Topic Probablity distribution by Document:
#  [[0.0179076  0.01793525 0.01793708 0.01792866 0.01790819 0.01806259
#   0.89232063]
#  [0.14285714 0.14285714 0.14285714 0.14285714 0.14285714 0.14285714
#   0.14285714]
#  [0.02384477 0.42275582 0.02386067 0.45787045 0.02390882 0.0238661
#   0.02389337]
#  [0.10605311 0.6197623  0.25369293 0.0051284  0.00512107 0.00512112
#   0.00512108]
#  [0.01431557 0.01430907 0.01429752 0.64059444 0.28778265 0.01435701
#   0.01434373]]

# %% [markdown]
# ##Differences in concerns and interests between visitors from the United States and the United Kingdom when visiting the theme parks?

# %%
import numpy as np


Selected_Countries = ['United States', 'United Kingdom']

Group_Prob = []
for i in range(len(Selected_Countries)):
    ReducedTerm_Selected = ReducedCount[np.where(df['Reviewer_Location'] == Selected_Countries[i])]
    TopicDis_Doc = lda.transform(ReducedTerm_Selected)
    Group_Prob.append(sum(TopicDis_Doc)/sum(sum(TopicDis_Doc)))


#Create a new figure
pyplot.figure(figsize=(7,4))
pyplot.title('Topic Distributions by Customer Group', fontsize=16)
pyplot.xlabel('Topic')
pyplot.ylabel('Probability')

width = 0.15
for i in range(len(Selected_Countries)):
    pyplot.bar(Bar_index + i*width, Group_Prob[i].tolist(), width,  label=Selected_Countries[i])

pyplot.xticks(Bar_index + 1.5*width, Bar_index)
pyplot.legend()
pyplot.show();

# %% [markdown]
# The analysis of topic distributions by customer group reveals distinct differences in concerns and interests between visitors from the United States and the United Kingdom. Visitors from the United Kingdom have a higher probability of concerns related to logistical aspects (Topic 1), indicating a focus on transportation and gathering points. In contrast, visitors from the United States show a higher probability in overall experience and ambiance (Topic 2) and specific attractions (Topic 4). These differences may stem from varying travel experiences and cultural preferences, with UK visitors potentially prioritizing efficient travel logistics and US visitors emphasizing the immersive experience and diverse attractions.

# %%
#installing Gensim package

# !pip install Cython
# !pip install gensim
# Out:
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (3.0.10)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (7.0.4)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim) (1.16.0)

# %% [markdown]
# Data Preperation

# %%
Cleaned_doc_new = []
print('CLEANED TEXT NEW: ')
for r in range(len(Cleaned_doc)):
    each_item = []
    for t in Cleaned_doc[r].split():
        #Keep only terms included in ReducedTerm
        if t in ReducedTerm:
             each_item.append(t)
    Cleaned_doc_new.append(each_item)
    print(Cleaned_doc_new[r])
# Out:
# Streaming output truncated to the last 5000 lines.
# ['stress', 'enjoy', 'head', 'nice', 'group', 'type', 'type', 'question', 'spot', 'jacket', 'smoke', 'fantasyland', 'small', 'good', 'better', 'carousel', 'snow', 'white', 'pinocchio', 'fine', 'problem', 'head', 'adventureland', 'disappoint', 'close', 'mention', 'shop', 'euro', 'heat', 'bite', 'cold', 'cold', 'later', 'cafe', 'item', 'menu', 'burger', 'nugget', 'work', 'group', 'later', 'long', 'cold', 'left', 'head', 'shop', 'stand', 'right', 'close', 'drink', 'check', 'card', 'cash', 'jacket', 'hall', 'hell', 'airport', 'sandwich']
# ['felt', 'vibe', 'wonder', 'feel', 'boyfriend', 'twice', 'watch', 'firework', 'wonder', 'music', 'feel', 'music', 'feel', 'light', 'walk', 'walk', 'feel', 'site', 'feel', 'dream', 'wonder', 'heart']
# ['mind', 'past', 'enjoy', 'small', 'face', 'french', 'beast', 'nice', 'small', 'nice', 'help', 'clean', 'rope', 'bathroom', 'glad', 'went', 'gate']
# ['french', 'took', 'half']
# ['guess']
# ['went', 'stay', 'santa', 'love', 'complaint', 'worth', 'good', 'love', 'lightyear', 'took', 'snack', 'cafe', 'good', 'rainforest', 'cafe', 'better', 'nugget', 'rush', 'left', 'stand', 'buffalo', 'worth', 'rude', 'push', 'good', 'travel', 'eurostar', 'express', 'work', 'nemo', 'recommend', 'saturday', 'rain', 'rain', 'head', 'studio', 'shelter', 'stitch', 'live', 'worth', 'care', 'fall', 'stop', 'make', 'stop', 'care', 'need', 'travel', 'eurostar', 'huge', 'fine', 'santa', 'didnt', 'fine', 'push']
# ['eurodisney', 'rain', 'august', 'enter', 'recommend']
# ['noon', 'step', 'went', 'kingdom', 'spectacular']
# ['best', 'saturday', 'sunday', 'avoid', 'alot', 'shop', 'outlet']
# ['extra', 'huge', 'layout', 'standard', 'clean', 'member', 'feel', 'member', 'lack', 'member', 'guest', 'member', 'smile', 'feel', 'disappoint', 'feel', 'guest', 'walk', 'lack', 'care', 'member', 'guest', 'disappoint', 'lack', 'stop', 'smoke', 'bathroom', 'step', 'standard', 'litter', 'small', 'long', 'litter', 'ground', 'smoke', 'smoke', 'good', 'version', 'twist', 'shop', 'look', 'good', 'luck', 'walk', 'wear', 'kind', 'shirt', 'hard', 'fact', 'later', 'hard', 'close', 'went', 'talk', 'search', 'close', 'sure', 'came', 'look', 'miss', 'total', 'small', 'color', 'scene', 'enjoy', 'shorter', 'love', 'think', 'miss', 'version', 'sure', 'good', 'state', 'think', 'need', 'good', 'good']
# ['need', 'phantom', 'manor', 'went', 'good', 'screen', 'film', 'young', 'small', 'long', 'burger']
# ['resort', 'recommend', 'transport', 'return', 'fare', 'pick', 'airport', 'pick', 'return', 'journey', 'help', 'santa', 'taxi', 'euro', 'make', 'airport', 'transport', 'later', 'refund', 'month', 'phone', 'refund', 'word', 'hard', 'post', 'advisor']
# ['stay', 'sequoia', 'love', 'best', 'fault', 'dream', 'worth', 'went', 'wonder', 'half', 'thought', 'good', 'mention', 'member', 'stay', 'member', 'charm', 'help', 'review', 'rude', 'went', 'make', 'sure']
# ['long', 'close']
# ['start', 'review', 'review', 'travel', 'diner', 'disappoint', 'good', 'hard', 'perfect', 'guest', 'perfect', 'stay', 'monday', 'friday', 'perfect', 'meet', 'right', 'review', 'section', 'brilliant', 'talk', 'member', 'toilet', 'garden', 'cafe', 'love', 'huge', 'effort', 'french', 'english', 'rubbish', 'switch', 'huge', 'brilliant', 'comment', 'guess', 'guest', 'problem', 'gate', 'hand', 'thank', 'smile', 'rude', 'guest', 'greet', 'love', 'smile', 'toilet', 'cafe', 'clean', 'litter', 'free', 'mention', 'guest', 'woman', 'drop', 'floor', 'right', 'foot', 'floor', 'wonder', 'wonder', 'height', 'went', 'brilliant', 'recommend', 'miss', 'small', 'twice', 'dragon', 'dumbo', 'boat', 'lightyear', 'laser', 'tour', 'robinson', 'tree', 'phantom', 'manor', 'went', 'peril', 'superb', 'word', 'treat', 'royal', 'stage', 'song', 'dozen', 'come', 'stage', 'mess', 'love', 'second', 'love', 'song', 'colour', 'dress', 'head', 'stage', 'watch', 'jedi', 'mini', 'jedi', 'brilliant', 'pixar', 'discoveryland', 'miss', 'long', 'right', 'meet', 'greet', 'worth', 'pluto', 'push', 'guest', 'love', 'kind', 'love', 'delight', 'make', 'cafe', 'comment', 'good', 'kind', 'hotdog', 'burger', 'cake', 'drink', 'recommend', 'good', 'right', 'pavement', 'stay', 'seat', 'work', 'treat', 'colour', 'music', 'firework', 'worth', 'stay', 'need', 'watch', 'good', 'good', 'spot', 'pack', 'flow', 'mass', 'felt', 'make', 'perfect', 'rush', 'need', 'feel', 'worth', 'come', 'love', 'second', 'thank', 'stay', 'ground', 'make', 'mind', 'studio', 'benefit', 'enter', 'central', 'shop', 'smaller', 'meet', 'greet', 'smaller', 'half', 'board', 'access', 'buffet', 'need', 'flow', 'think', 'work', 'bear', 'work', 'rest', 'pick', 'pain', 'later', 'stick', 'total', 'worth', 'brilliant', 'donald', 'duck', 'superb', 'stitch', 'stop', 'thank']
# ['enjoy', 'spent', 'long', 'need']
# ['shop', 'outlet', 'long', 'visitor', 'smoke', 'manner', 'enjoy', 'help', 'close', 'best', 'firework', 'display']
# ['frontierland', 'dream']
# ['worth', 'good', 'good', 'huge', 'june', 'huge', 'stay', 'access', 'extra', 'start']
# ['went', 'busier', 'went', 'long', 'thrill', 'disappoint', 'action', 'later', 'light', 'firework', 'display', 'worth']
# ['watch', 'work', 'midnight']
# ['love', 'firework', 'display', 'need', 'close', 'pink', 'hard', 'firework']
# ['went', 'yesterday', 'pizza', 'pasta', 'poor', 'american', 'french', 'iron', 'come', 'treat', 'care', 'worth', 'rate']
# ['nice', 'stay', 'studio']
# ['close', 'small', 'miss']
# ['yesterday', 'went', 'good', 'deal', 'went', 'stay', 'newport', 'club', 'help', 'clean', 'newport', 'walk', 'tram', 'newport', 'club', 'check', 'bite', 'problem', 'need', 'went', 'spent', 'half', 'stay', 'ball', 'small', 'avoid', 'comment', 'site', 'smoke', 'smoke', 'smoke', 'hand', 'smoke', 'hope', 'good', 'april', 'good', 'thursday', 'saturday', 'huge', 'long', 'thrill', 'long', 'small', 'small', 'charm', 'enjoy', 'went', 'twice', 'pick', 'good', 'spot', 'view', 'thursday', 'friday', 'avoid', 'mass', 'saturday', 'studio', 'wise', 'studio', 'enjoy', 'worth', 'good', 'half', 'studio', 'highlight', 'studio', 'tram', 'tour', 'aerosmith', 'word', 'comment', 'shop', 'studio', 'rule', 'word', 'info', 'watch', 'board', 'stroller', 'hope', 'comment']
# ['fair', 'comparison', 'good', 'effort', 'clean', 'smaller', 'feel', 'toilet', 'review', 'comparison', 'feel', 'opinion']
# ['clean', 'wonder', 'enter', 'stay', 'walk', 'transport', 'work', 'warm']
# ['spent', 'half', 'stay', 'clean', 'nice', 'thought', 'better', 'standard', 'stay', 'french', 'smile', 'supermarket', 'snack', 'mcdonald']
# ['went', 'thursday', 'friday', 'twice', 'extra', 'rest', 'miss', 'feel', 'smile', 'better']
# ['spirit', 'member', 'rude', 'english', 'guest', 'trash', 'floor', 'wonder', 'member']
# ['travel', 'young', 'think', 'mcdonald', 'look', 'size', 'thrill', 'factor', 'tower', 'terror', 'travel', 'factor', 'island', 'parc', 'parc', 'clean', 'tree', 'went', 'order', 'work', 'cart', 'friend', 'later', 'close', 'felt', 'fine', 'skip', 'cool', 'work', 'stand', 'winter', 'check', 'discount', 'refund', 'month', 'better', 'enjoy', 'best', 'feel', 'think', 'need']
# ['help', 'meet', 'help', 'walk', 'mile', 'comfort', 'recommend']
# ['make', 'autopia', 'felt', 'stand', 'long', 'autopia', 'long', 'worth', 'speed', 'process', 'went', 'worth', 'autopia', 'went', 'snow', 'stop', 'extra', 'stay', 'help', 'shop', 'store']
# ['love', 'parc', 'studio', 'parc', 'love', 'decor', 'phantom', 'manor', 'dark', 'avoid', 'avoid', 'long']
# ['charm', 'work', 'live', 'cold', 'french', 'think', 'okay', 'review', 'start', 'studio', 'half', 'studio', 'worth', 'close', 'twice', 'good', 'discoveryland', 'best', 'version', 'tomorrowland', 'think', 'better', 'cold', 'make', 'feel', 'thought', 'tour', 'close', 'felt', 'adventureland', 'frontierland', 'member', 'warm', 'cold', 'member', 'feel', 'studio', 'charm', 'post', 'look', 'need', 'soarin', 'thought', 'cold', 'right', 'frame', 'mind', 'barrier', 'miss', 'best', 'think', 'heart']
# ['love', 'access', 'pricey', 'pricey', 'minimum', 'euro', 'total', 'euro', 'meet', 'sure', 'look']
# ['love', 'took', 'month', 'love', 'long', 'buffet', 'good', 'stay', 'crockett', 'ranch', 'self', 'nice', 'drive', 'rain', 'need', 'euro', 'nice']
# ['cover', 'need', 'minimum', 'think', 'best', 'forget']
# ['nice', 'patch', 'american', 'version', 'good', 'good', 'feel']
# ['eurostar', 'express', 'good', 'clean', 'toilet', 'good', 'enjoy', 'rude', 'member', 'english', 'stop', 'american', 'smoke', 'feet', 'come', 'hand', 'walk', 'ground', 'height', 'head', 'face', 'smoke', 'design', 'feel', 'eurostar', 'eurostar', 'fact', 'site', 'eurostar', 'site', 'barrier', 'lift', 'right', 'eurostar', 'check', 'mark', 'coach', 'seat', 'small', 'shop', 'express', 'floor', 'hand', 'step', 'door', 'stay', 'went', 'check', 'check', 'hand', 'went', 'rest', 'later', 'drop', 'eurostar', 'check', 'counter', 'straight', 'check', 'passport', 'barrier', 'lift']
# ['took', 'took', 'smaller', 'style', 'clean', 'think', 'disappoint', 'french', 'american', 'limit', 'popcorn', 'corn', 'dole', 'whip', 'turkey', 'glad', 'went']
# ['past', 'rude', 'return', 'return', 'shame', 'good', 'crush', 'tower', 'terror', 'live', 'aerosmith', 'felt', 'snow', 'ground', 'sort', 'mess']
# ['spent', 'feel', 'shock', 'paper', 'toilet', 'sign', 'toilet', 'poor', 'studio', 'slot', 'better', 'studio', 'better', 'studio', 'worth', 'need', 'dont', 'miss', 'light']
# ['turn', 'start', 'miss', 'moment', 'look', 'bathroom', 'work', 'need', 'good', 'look', 'help', 'spent', 'delight', 'think', 'need']
# ['sunday', 'went', 'help', 'best', 'member', 'enjoy', 'make', 'shop', 'pack', 'hard', 'spent', 'look']
# ['took', 'shorter']
# ['love', 'eurodisney', 'thought', 'good', 'souvenir', 'close', 'close', 'close', 'firework', 'half', 'dark', 'cold', 'shut', 'bathroom', 'close']
# ['august', 'check', 'reason', 'dream', 'problem', 'left', 'pavement', 'transport']
# ['went', 'brilliant', 'live', 'dream', 'stay', 'forget', 'recommend', 'young']
# ['thrill', 'went', 'recommend']
# ['hill', 'best', 'walk', 'patch', 'reason', 'return']
# ['thank', 'perfect', 'wise', 'cold', 'second', 'limit', 'shop', 'disappoint', 'offer', 'firework', 'glad', 'went', 'need', 'walk', 'left']
# ['huge', 'pure', 'euro', 'rate', 'mind', 'small', 'stay', 'mcdonald', 'came', 'mind', 'good', 'offer', 'resort', 'good', 'good', 'planet', 'hollywood', 'wall', 'felt', 'euro', 'burger', 'small', 'portion', 'date', 'come', 'planet', 'hollywood']
# ['return', 'long', 'friday', 'saturday', 'sunday', 'come', 'young']
# ['love', 'went', 'felt']
# ['worker', 'english', 'love']
# ['love', 'stay', 'santa', 'clean', 'clean', 'half', 'board', 'worth', 'resort', 'make', 'roll', 'mind', 'plastic', 'young', 'glass', 'right', 'drive', 'journey', 'sign', 'make', 'sure', 'sure', 'hire', 'walk', 'euro', 'reason', 'drink', 'check', 'hope', 'stay', 'santa', 'start', 'express', 'drive']
# ['went', 'tokyo', 'kingdom', 'version', 'bunch', 'fantasyland', 'august', 'club', 'long', 'wise', 'peak', 'phantom', 'manor', 'nice', 'love', 'version', 'phantom', 'manor', 'version', 'notch', 'small', 'color', 'dragon', 'live', 'island', 'tunnel', 'start', 'love', 'store', 'idea', 'firework', 'avoid', 'mass', 'member', 'smoke', 'design', 'smoke', 'zone', 'member', 'guest', 'smoke', 'smoke', 'deal', 'second', 'better', 'french', 'think', 'help', 'avoid', 'problem', 'make', 'dress', 'control', 'case', 'guest', 'jump', 'past', 'check', 'come', 'fine']
# ['best', 'stay', 'went', 'love', 'better']
# ['went', 'southern', 'matterhorn', 'fantasyland', 'half', 'good', 'thought', 'better', 'socal', 'smaller', 'hand', 'check']
# ['took', 'perfect', 'took', 'extra', 'came', 'limit', 'best', 'term', 'went', 'height', 'studio', 'saturday', 'long', 'cafe', 'come', 'whilst', 'close', 'whilst', 'limit', 'burger', 'chip', 'small', 'shop', 'sandwich']
# ['jack', 'highlight', 'rate', 'cafe', 'stay', 'review', 'later', 'stay', 'reason', 'review', 'note', 'guess', 'phone', 'check', 'pizza', 'planet', 'close', 'close', 'disappoint', 'pizza', 'planet', 'list']
# ['childhood', 'best', 'order', 'enjoy', 'need', 'stay', 'cover']
# ['went', 'half', 'term', 'took', 'shock', 'toilet', 'miss', 'burger', 'euro', 'left', 'total', 'half', 'term', 'total', 'shame']
# ['treat', 'cold', 'complaint', 'enjoy', 'good', 'better', 'york', 'good', 'idea', 'stay', 'extra', 'work', 'warm', 'cold', 'crush', 'second', 'smoke', 'smoke', 'feel', 'smoke', 'worth', 'smoke', 'right', 'smoke', 'fair', 'euro', 'bite', 'bear', 'walk', 'shop', 'taxi', 'drive', 'euro', 'better', 'york', 'fine', 'clean', 'english', 'news', 'enjoy', 'stay', 'hire', 'good', 'york', 'enjoy']
# ['came', 'spent', 'love', 'look', 'menu', 'labyrinth', 'sure', 'barrier', 'english', 'went', 'round', 'captain', 'hook', 'dumbo', 'good', 'stuff', 'meet', 'captain', 'hook', 'king', 'stitch', 'make', 'sure', 'start', 'turn', 'make', 'effort', 'play', 'firework', 'love', 'dragon', 'love', 'shop', 'stuff', 'shop', 'fine', 'paint', 'post', 'airport', 'look', 'section', 'look', 'wonder', 'help']
# ['american', 'felt', 'enjoy', 'lack', 'spot', 'cold', 'good', 'nice', 'look', 'comfort', 'cold', 'style', 'studio', 'small', 'euro', 'look', 'close', 'spot', 'brand', 'small', 'metro', 'mark', 'return', 'stay', 'site', 'thrill', 'spin', 'feel', 'idea']
# ['happiest', 'love', 'resort', 'think', 'review', 'good', 'huge', 'need', 'better', 'best', 'crush', 'tower', 'terror', 'autopia']
# ['holder', 'love', 'enjoy', 'need', 'china', 'need', 'idea', 'item', 'walk', 'best', 'better', 'shop', 'best', 'shop', 'item', 'member', 'meet', 'share', 'share', 'counter', 'menu', 'came', 'drink', 'counter', 'layout', 'look', 'wonder', 'enjoy', 'enjoy', 'watch']
# ['second', 'left', 'shanghai', 'deal', 'cold', 'splash', 'disappoint', 'best', 'option', 'good', 'burger', 'junk', 'close', 'guess', 'watch', 'smoke', 'parent', 'second', 'hand', 'smoke', 'think', 'light', 'rain', 'santa']
# ['disappoint', 'smaller', 'scale', 'sister', 'french', 'deal', 'manner', 'travel', 'autograph', 'control', 'push', 'stay', 'kind', 'make', 'enjoy', 'make', 'sure', 'stay', 'firework', 'matter', 'stay']
# ['stay', 'friend', 'enjoy', 'childhood', 'went', 'meant', 'long', 'zone', 'wonderland', 'went', 'recommend', 'stay', 'need', 'long', 'offer']
# ['clean', 'recommend', 'recommend', 'school', 'avoid', 'dont', 'miss', 'brilliant']
# ['group', 'tour', 'group', 'long', 'limit', 'walk', 'section', 'good', 'enjoy', 'light']
# ['meet', 'film', 'reason', 'whilst', 'half', 'whilst', 'tunnel', 'shut', 'didnt']
# ['camera']
# ['peak', 'close', 'sign', 'enjoy', 'come', 'australia', 'mark', 'half', 'close', 'half', 'good', 'legoland', 'london']
# ['come', 'make', 'better', 'reason', 'lack', 'order', 'event', 'disappoint', 'event', 'bring', 'sandwich', 'poor', 'bring', 'cash', 'treat', 'popcorn', 'shop', 'till', 'stuff', 'small', 'stroller', 'walk']
# ['second', 'resort', 'event', 'best', 'friday', 'sunday', 'good', 'worker', 'work', 'good', 'personnel', 'play', 'occasion', 'smoke', 'rule', 'smoke', 'smoke', 'whilst', 'walk', 'smoke', 'whilst', 'smoke', 'smoke', 'zone', 'help', 'smoke', 'sign', 'drink', 'euro', 'rate', 'make', 'coke', 'toilet', 'young', 'love', 'love', 'reason', 'america', 'good', 'shame', 'long', 'cover']
# ['quieter', 'forget']
# ['mark', 'bucket', 'list', 'dream', 'make', 'love', 'disappoint', 'long', 'went', 'think', 'hope']
# ['friend', 'love', 'meet', 'stuff', 'need', 'charm', 'school', 'problem', 'went', 'highlight', 'work', 'recommend', 'buffet', 'menu', 'better', 'buffet', 'opinion', 'come', 'buffet', 'long', 'seat', 'make', 'care', 'better', 'half']
# ['went', 'love', 'disappoint', 'recommend']
# ['close', 'offer', 'firework', 'display', 'section', 'offer', 'need', 'discoveryland', 'wonderland', 'huge', 'offer', 'buffet', 'stay', 'sequoia', 'offer', 'view', 'studio', 'opinion', 'better', 'make', 'review']
# ['sure', 'disappoint', 'thrill', 'close', 'small', 'bring', 'good']
# ['friend', 'sure', 'enjoy', 'transport']
# ['half', 'term', 'stay', 'love', 'walk', 'love', 'shop', 'look', 'didnt', 'long', 'glad', 'need', 'rest', 'love', 'fuss', 'love', 'took', 'long', 'thought', 'love', 'review', 'fine', 'cafe', 'love', 'light', 'pizza', 'planet', 'casey', 'burger', 'studio', 'fault', 'blue', 'lagoon', 'best', 'treat', 'went', 'stage', 'right', 'light', 'good', 'spot', 'stay', 'watch', 'whilst', 'light', 'pizza', 'planet', 'thought', 'good', 'play', 'love', 'live', 'stage', 'went', 'came', 'fault', 'thank']
# ['standard', 'past', 'lack', 'stay', 'york', 'meat', 'fruit', 'bread', 'extra', 'hand', 'head', 'later', 'better', 'discount', 'close', 'access', 'later', 'stay', 'access', 'public', 'option', 'better', 'option', 'childhood', 'dream', 'matter']
# ['long', 'brilliant', 'group', 'long', 'enjoy']
# ['dream', 'light', 'spectacular', 'profit', 'light', 'drink', 'enjoy', 'offer', 'best', 'gripe', 'smoke', 'smoke', 'need', 'rule', 'shock', 'pavillion', 'sure', 'better', 'meet', 'greet', 'need', 'better', 'free', 'rude', 'care', 'young', 'turn', 'bring', 'best', 'regardless']
# ['rude', 'smoke', 'option', 'salad', 'fruit', 'close', 'cold']
# ['good', 'smaller', 'need', 'august', 'small', 'avoid', 'taxi', 'transfer', 'mile', 'minimum', 'euro', 'euro', 'taxi', 'driver', 'need', 'stop', 'need', 'transfer', 'central', 'london', 'good', 'long', 'journey', 'taxi', 'transfer', 'small', 'eurostar', 'stay', 'half', 'board', 'option', 'meant', 'half', 'board', 'option', 'avoid', 'bank', 'buffet', 'half', 'board', 'option', 'limit', 'euro', 'junk', 'better', 'euro', 'head', 'earl', 'sandwich', 'best', 'option', 'need', 'need', 'action', 'option', 'reason', 'taxi', 'make', 'better', 'option']
# ['wonder', 'matter', 'drink', 'worth']
# ['nice', 'meet', 'work', 'worth', 'order', 'answer', 'question', 'block', 'make', 'nice', 'worth', 'long', 'return', 'look', 'sunscreen', 'store', 'shop', 'stop', 'nice', 'help', 'shop', 'sunscreen', 'shop', 'sunscreen', 'love', 'benefit']
# ['review', 'half', 'term', 'nice', 'kind', 'mini', 'love', 'love', 'watch', 'second', 'stay', 'swim', 'pool', 'enjoy', 'love', 'cold']
# ['stay', 'crockett', 'ranch', 'work', 'stay', 'meant', 'free', 'moment', 'walk', 'love', 'clean', 'better', 'tower', 'terror', 'love', 'stitch', 'live', 'enjoy', 'stunt', 'film', 'effect', 'comment', 'jump', 'alton', 'tower', 'work', 'miss', 'brilliant', 'twice', 'standard', 'burger', 'nice', 'good', 'return']
# ['dream']
# ['think', 'meet', 'play', 'darth', 'vader', 'shop', 'souvenir', 'recommend', 'right', 'wonder', 'winter', 'cold', 'close', 'make', 'sure', 'start']
# ['took', 'drink', 'snack', 'spent', 'long', 'sunday', 'monday', 'half']
# ['toddler', 'close', 'enjoy', 'result', 'small', 'free', 'start', 'later', 'felt', 'total']
# ['enjoy', 'work', 'hard', 'snow', 'felt', 'small', 'coke', 'snack']
# ['thought', 'standard', 'need', 'think', 'enjoy', 'health', 'question', 'event', 'kingdom', 'term', 'pack', 'floor', 'return', 'music', 'poor', 'version', 'hope', 'comment', 'make', 'better', 'visitor']
# ['young', 'return', 'period', 'spent', 'enjoy', 'whilst', 'april', 'good', 'recommend', 'close', 'enjoy', 'offer', 'enjoy', 'shop', 'cheap']
# ['good', 'standard', 'paint', 'work', 'ground', 'rude', 'disappoint', 'meet']
# ['disappoint', 'hand', 'close', 'close', 'rude', 'feel', 'fact', 'look', 'email', 'live']
# ['kind', 'type', 'meet', 'everyday']
# ['better', 'close', 'guess', 'weekday', 'quieter', 'watch', 'dream', 'firework', 'need', 'face', 'stand', 'half', 'scene', 'lion', 'king', 'section', 'start', 'exit', 'start', 'make', 'exit', 'avoid', 'rush', 'cream', 'shop', 'reason', 'lightyear', 'jedi', 'seat', 'return']
# ['step', 'best', 'till', 'love']
# ['disappoint', 'went', 'standard', 'wall', 'dumbo', 'toilet', 'twice', 'lightyear', 'extra', 'joke', 'lack', 'meant', 'visitor', 'check', 'outlet', 'close', 'half', 'toddler', 'sure', 'long', 'till', 'float', 'shorter', 'lack', 'meet', 'greet', 'donald', 'decor', 'rest', 'behaviour', 'problem', 'meant', 'straight', 'blue', 'lagoon', 'steak', 'good', 'dream', 'good', 'decor']
# ['board', 'come', 'later', 'half', 'came', 'need', 'better', 'light', 'start', 'half', 'stand', 'cold', 'poor']
# ['love', 'spent', 'cold', 'stop', 'enjoy', 'nice', 'good', 'good', 'disappoint', 'english', 'wear', 'english', 'option', 'french', 'disappoint', 'meet', 'greet', 'sign', 'good', 'best', 'counter', 'shock', 'guest', 'rude', 'stand', 'past', 'fault', 'love', 'firework', 'light']
# ['nice', 'love', 'enjoy', 'childhood']
# ['went', 'good', 'enjoy', 'american', 'worth', 'note', 'hope', 'bring', 'chip', 'burger', 'good', 'smoke', 'young', 'smoke', 'smoke', 'rude', 'member', 'roll', 'french', 'rude', 'french', 'order', 'perfect', 'gift', 'shop', 'make', 'feel', 'face', 'tourist', 'make', 'huge', 'visitor', 'make', 'good']
# ['enjoy']
# ['travel', 'best', 'perfect', 'clean', 'toilet', 'floor', 'floor', 'help', 'kind', 'make', 'best', 'option', 'concern', 'drink', 'pizza', 'salad', 'look', 'guess', 'matter', 'come', 'theater', 'watch', 'love', 'shop', 'thrill']
# ['pick', 'glass', 'pick', 'head', 'thought', 'touch', 'glass', 'pick', 'glass', 'member', 'question', 'shame', 'need']
# ['half', 'board', 'stay', 'review', 'august', 'walk', 'walk', 'brilliant', 'holder', 'stay', 'left', 'recommend', 'download', 'close', 'make', 'smile', 'face', 'best', 'young', 'small', 'enjoy', 'small', 'boat', 'past', 'recommend', 'music', 'travel', 'boat', 'young', 'float', 'huge', 'breath', 'dragon', 'check', 'rider', 'height', 'access', 'peril', 'good', 'long', 'fault', 'worth', 'enjoy', 'dark', 'light', 'huge', 'screen', 'scene', 'sound', 'effect', 'music', 'loop', 'fault', 'exit', 'fault', 'shame', 'long', 'return', 'check', 'guess', 'fault', 'mention', 'tour', 'meet', 'feel', 'miss', 'spectacular', 'firework', 'display', 'video', 'firework', 'effect', 'light', 'laser', 'music', 'sound', 'huge', 'smile', 'face', 'long', 'display', 'start', 'think', 'good', 'toilet', 'clean', 'recommend', 'care', 'recommend', 'stay', 'travel', 'think', 'month', 'forget', 'autograph', 'young', 'guest', 'meet', 'greet', 'long', 'worth', 'smile', 'recommend', 'euro', 'come', 'card', 'small', 'card', 'member', 'need', 'card', 'booth', 'member', 'store', 'download', 'print', 'view', 'recommend']
# ['euro', 'central', 'took', 'right', 'card', 'studio', 'head', 'studio', 'close', 'went', 'hollywood', 'tower', 'terror', 'rock', 'crush', 'straight', 'went', 'stay']
# ['display', 'size', 'shop', 'option']
# ['walk', 'cafe', 'nice', 'cool']
# ['april', 'easter', 'school', 'french', 'school', 'tuesday', 'check', 'sequoia', 'extra', 'make', 'storybook', 'casey', 'junior', 'casey', 'junior', 'later', 'head', 'feel', 'close', 'close', 'disappoint', 'enjoy', 'express', 'stop', 'dream', 'work', 'screen', 'white', 'enjoy', 'recommend', 'check', 'board', 'good']
# ['nicer', 'railway', 'indoor', 'music', 'aerosmith', 'dark', 'tower', 'terror', 'fall', 'glad']
# ['travel', 'delight', 'huge', 'need', 'walk', 'stand', 'long', 'meet', 'wallet', 'pricey', 'poor', 'euro', 'highlight', 'grand', 'super', 'come']
# ['budget', 'feel', 'walk', 'make', 'long', 'need', 'shop', 'spirit']
# ['cartoon']
# ['love', 'thought', 'worth', 'come', 'close', 'disappoint', 'good', 'ship', 'alot', 'need', 'paint', 'look', 'didnt', 'dress', 'euro', 'euro', 'euro', 'disappoint']
# ['rude', 'dont', 'rubbish', 'heat', 'think', 'return', 'america', 'lack', 'rude']
# ['brilliant', 'close', 'good', 'good', 'toilet', 'mass', 'check', 'clean', 'love']
# ['walk', 'gate', 'help', 'skip', 'make', 'feel', 'french', 'feel', 'look', 'went', 'peak', 'close']
# ['parent', 'traffic', 'fine', 'june', 'weekday', 'fine', 'check', 'garden', 'layout', 'clean', 'litter', 'phone', 'work', 'jump', 'period', 'period', 'come', 'later', 'best', 'need', 'shade', 'shade', 'nice', 'focus', 'stand', 'barrier', 'risk', 'guess', 'small', 'bench', 'rest', 'avoid', 'health', 'barrier', 'think', 'make', 'cartoon', 'make', 'stand', 'best', 'cartoon', 'think', 'good', 'camera', 'feel', 'went', 'heat', 'came', 'cool', 'hard', 'extra', 'long', 'cheap', 'plastic', 'head', 'premium', 'look', 'burger', 'chip', 'drink', 'think', 'reason', 'menu', 'marvel', 'came', 'need', 'control', 'disappoint', 'better', 'seat', 'start', 'iron', 'problem', 'later', 'long', 'access', 'feel', 'good', 'cheap', 'make', 'better', 'make', 'better', 'thought']
# ['euro', 'resort', 'marne', 'love']
# ['light', 'firework', 'display', 'wheelchair', 'help']
# ['watch', 'stunt', 'watch', 'view', 'lazer', 'firework', 'worth', 'stay', 'drink', 'walk', 'watch', 'need', 'autograph']
# ['small']
# ['enjoy', 'need', 'enjoy', 'studio', 'enjoy', 'enjoy', 'autopia', 'mission', 'round', 'dumbo', 'shop', 'height']
# ['french', 'american', 'kingdom', 'lack', 'poor', 'phantom', 'manor', 'half', 'hair', 'close', 'american', 'french', 'french', 'smoke', 'sign', 'section', 'enjoy', 'past', 'look', 'wallet', 'crap', 'review', 'avoid', 'look', 'parc', 'right', 'road']
# ['second', 'felt', 'date', 'need', 'spent', 'bring', 'feel', 'close', 'felt', 'school', 'walk', 'autograph', 'sure', 'disappoint', 'member', 'stand', 'nice', 'disappoint', 'long', 'picnic', 'brilliant', 'standard', 'good', 'fountain', 'firework', 'light', 'brilliant', 'grandchildren', 'brilliant', 'long']
# ['disappoint', 'menu', 'drink', 'burger', 'type', 'market', 'stay', 'ranch', 'crockett', 'self', 'shop', 'site', 'shop']
# ['make', 'cheap', 'make', 'sure', 'look', 'deal', 'deal', 'captain', 'jack', 'sparrow', 'good', 'firework', 'good', 'reason', 'think', 'rider']
# ['took', 'stop', 'right', 'clean', 'walk']
# ['eurodisney', 'state', 'look', 'feel', 'state', 'stuff', 'french', 'work', 'lack', 'hope', 'wonder', 'hard', 'look', 'good', 'design', 'american', 'king', 'game', 'town', 'sale', 'member', 'work', 'good', 'popcorn', 'smile', 'hard', 'hire']
# ['gate', 'internet', 'bring', 'site']
# ['group', 'enjoy', 'later', 'cowboy', 'walk', 'left', 'enjoy']
# ['straight', 'walk', 'return', 'took', 'recommend', 'young', 'need', 'sequoia', 'sure', 'check', 'drop', 'nice', 'look', 'site', 'clean', 'need', 'best', 'walk', 'good', 'took', 'store', 'sandwich', 'drink', 'went', 'pool', 'pool', 'close', 'cafe', 'thank', 'good', 'walk', 'past', 'half', 'board', 'option', 'event', 'came', 'play', 'love', 'face', 'love', 'love', 'start', 'silver', 'frontierland', 'spent', 'nice', 'limit', 'pizza', 'fish', 'burger', 'waiter', 'enjoy', 'buffet', 'buffet', 'salad', 'good', 'good', 'dessert', 'bread', 'glad', 'bowl', 'soup', 'bread', 'start', 'sort', 'buffet', 'drink', 'poor', 'alton', 'tower', 'legoland', 'took', 'snack', 'drink', 'drink', 'love', 'busier', 'rest', 'studio', 'watch', 'stunt', 'walk', 'straight', 'discoveryland', 'think', 'went', 'feet', 'later', 'studio', 'rude', 'smoke', 'stay', 'resort', 'love', 'school', 'french', 'smile', 'enjoy', 'regardless', 'came', 'play', 'snack', 'drink', 'shop', 'enjoy']
# ['vision', 'close', 'meant', 'miss', 'firework', 'bummer', 'rain', 'thank', 'long', 'close', 'disappoint', 'english', 'work', 'skip', 'size', 'childhood', 'enjoy', 'studio', 'class', 'sort', 'worth', 'stick', 'young']
# ['question', 'miss', 'firework', 'laser', 'wonder', 'white', 'effect', 'carribean', 'brilliant', 'film', 'ghost', 'small', 'charm', 'miss', 'dragon', 'cheap', 'cafe', 'offer', 'euro', 'euro', 'euro', 'drink', 'drink', 'pick', 'forget', 'beer', 'word', 'shop', 'design', 'care', 'marvel']
# ['help', 'childhood']
# ['brilliant', 'love', 'girl', 'hope', 'nice', 'dream', 'come']
# ['better', 'better', 'member', 'rude', 'meet']
# ['fault', 'drink']
# ['eurodisney', 'twice', 'hill', 'look', 'half', 'term', 'close', 'need', 'felt', 'frontier', 'close', 'close', 'america']
# ['come', 'stay', 'santa', 'look', 'shop', 'worth', 'souvenir', 'whilst', 'went', 'wild', 'west', 'buffalo', 'recommend', 'good', 'thought', 'recommend', 'problem', 'king', 'size', 'small', 'drink', 'self', 'clean', 'litter', 'english', 'effort', 'shop', 'outlet', 'whilst', 'recommend', 'visitor', 'manor', 'good', 'effort', 'head', 'talk', 'ghost', 'good', 'good', 'meet', 'jack', 'sparrow', 'good', 'pinocchio', 'small', 'good', 'small', 'mission', 'light', 'effect', 'rest', 'tour', 'effort', 'whilst', 'worth', 'effect', 'cinema', 'cinderella', 'charm', 'travel', 'spent', 'blue', 'lagoon', 'type', 'recommend', 'love', 'float', 'light', 'studio', 'thought', 'stitch', 'live', 'stitch', 'start', 'talk', 'live', 'good', 'worth', 'stunt', 'stunt', 'recommend', 'watch', 'disappoint', 'nemo', 'better', 'think', 'hollywood', 'tower', 'terror', 'help', 'lift', 'drop', 'ground', 'long', 'review', 'worth']
# ['huge', 'version', 'feel', 'america', 'tigger', 'clean', 'peak', 'meant', 'wonder', 'best', 'matter']
# ['recommend', 'euro', 'hope', 'right', 'gate', 'style', 'grand', 'enjoy', 'clean', 'help', 'worth']
# ['went', 'august', 'french', 'bank', 'long', 'track', 'booth', 'close', 'enjoy', 'firework', 'display', 'close', 'outlet', 'shop', 'reason', 'drink', 'cream', 'didnt']
# ['twist', 'relax', 'rush', 'nemo', 'went', 'come', 'bring', 'limit', 'option', 'drink']
# ['review', 'enjoy', 'went', 'right', 'shut', 'help', 'firework']
# ['wonder', 'thought', 'worth', 'highlight', 'free', 'need', 'free', 'stay', 'comment', 'free', 'outlet', 'free', 'look', 'free', 'chip', 'free', 'question', 'free', 'menu', 'item', 'free', 'type', 'small', 'pack', 'snack']
# ['review', 'rubbish', 'lack', 'order', 'lack', 'enthusiasm', 'order', 'push', 'rude', 'toilet', 'went', 'pain', 'disappoint']
# ['glad', 'light', 'close']
# ['close', 'poor', 'work', 'make', 'sure', 'best', 'clean']
# ['smaller', 'version', 'close', 'problem', 'come', 'close', 'noon']
# ['month', 'tour', 'highlight', 'start', 'whilst', 'hand', 'miss', 'discount', 'gate', 'euro', 'went', 'close', 'euro', 'order', 'gate', 'joke', 'fact', 'mcdonald', 'think', 'euro', 'smaller', 'stunt', 'better', 'enjoy', 'benefit', 'moment', 'royal']
# ['enjoy', 'good', 'right', 'make', 'fine', 'right', 'feel', 'sign', 'case', 'reason', 'come', 'best', 'rest']
# ['stay', 'worth', 'public', 'work', 'quieter', 'later', 'miss', 'display', 'close', 'brilliant', 'need', 'good', 'spot', 'pack']
# ['stay', 'enjoy', 'spent', 'flight', 'internet', 'best', 'rock', 'roll', 'carribean', 'miss', 'stunt', 'spectacular', 'blue', 'lagoon', 'disappoint', 'quarter', 'better', 'good', 'resort', 'good', 'wear', 'comfort', 'saturday', 'sunday', 'forget']
# ['kingdom', 'meet', 'watch', 'frozen', 'lover', 'free', 'idea', 'need', 'return', 'skip', 'straight', 'best', 'phantom', 'ghost', 'twice', 'free', 'make', 'sure', 'shop', 'good', 'idea']
# ['went', 'took', 'love', 'firework', 'light']
# ['stay', 'perfect', 'went', 'spectacular', 'enjoy', 'review', 'thought', 'rude', 'went', 'step', 'feel', 'love', 'spent', 'perfect', 'month']
# ['gate', 'enter', 'airport', 'walk', 'enter', 'event', 'phone', 'enter', 'snack', 'item', 'small', 'snack', 'american', 'style', 'store', 'central', 'access', 'tale', 'shop', 'download', 'help', 'need', 'good', 'view', 'music', 'firework', 'display', 'miss', 'firework', 'whilst', 'firework', 'enjoy']
# ['rest', 'start', 'thrill', 'enjoy', 'long', 'half', 'term', 'worth', 'cheap', 'think', 'enjoy']
# ['total', 'love', 'come', 'walk', 'hell', 'shop', 'super', 'tour', 'meet', 'highlight', 'miss']
# ['good', 'tower', 'terror', 'member', 'discount', 'refund', 'discount', 'second', 'euro', 'hopper', 'miss', 'best', 'bring', 'look', 'chip', 'euro', 'went', 'miss', 'state', 'shut', 'gate', 'control', 'need', 'loop', 'loop', 'disappoint', 'guest']
# ['spent', 'come', 'shop', 'beast', 'lion', 'king', 'aladdin', 'shop', 'stitch', 'stitch', 'self', 'need', 'studio', 'small']
# ['small', 'nice', 'smaller', 'joke', 'wifi', 'paper', 'doubt', 'need']
# ['good', 'cream', 'toilet', 'doubt', 'return', 'fact']
# ['cartoon', 'right', 'spent', 'walk', 'shop', 'souvenir', 'came', 'friend']
# ['past', 'rush', 'small', 'coke', 'small', 'glass', 'wine', 'gift', 'friend', 'shirt', 'size', 'best', 'small', 'voucher', 'good', 'good', 'good', 'feel', 'good', 'recommend']
# ['friday', 'grandson', 'studio', 'check', 'santa', 'euro', 'deposit', 'problem', 'need', 'deposit', 'spent', 'nice', 'good', 'control', 'smile', 'joke', 'total', 'need', 'corner', 'best', 'plane', 'work', 'mention', 'help', 'gate', 'track', 'small', 'enjoy', 'lightyear', 'studio', 'right', 'stitch', 'stunt', 'relax', 'mention', 'good', 'santa', 'good', 'meat', 'english', 'bread', 'stop', 'standard', 'half', 'board', 'voucher', 'worth', 'buffet', 'premium', 'treat', 'cheap', 'treat', 'nice', 'sort', 'good']
# ['long', 'problem', 'stop', 'close', 'half', 'work', 'period', 'tower', 'terror', 'studio', 'work', 'group', 'jump', 'respect']
# ['spent', 'mind', 'good', 'mood', 'stay', 'thank', 'stay', 'light', 'music']
# ['stay', 'close', 'crockett', 'ranch', 'drive', 'better', 'help', 'member', 'good', 'grandchildren', 'delight', 'stay', 'better', 'site', 'young', 'comfort', 'stay', 'site', 'better']
# ['love', 'wonderland', 'worth', 'firework']
# ['return', 'stay', 'york', 'york', 'travel', 'eurostar', 'month', 'month', 'review', 'eurodisney', 'eurostar', 'small', 'warm', 'milk', 'went', 'drink', 'snack', 'warm', 'milk', 'warm', 'milk', 'stay', 'york', 'york', 'stay', 'travel', 'stay', 'work', 'worth', 'dont', 'need', 'milk', 'warm', 'went', 'pushchair', 'problem', 'center', 'kingdom', 'didnt', 'feel', 'need', 'make', 'sure', 'recommend', 'health', 'visitor', 'travel', 'make', 'milk', 'hope', 'help', 'need', 'thank']
# ['come', 'return']
# ['went', 'decor', 'good', 'look']
# ['travel', 'dream', 'come', 'benefit', 'turn', 'push', 'past', 'gate', 'voucher', 'quicker', 'went', 'america', 'music', 'play', 'fact', 'sound', 'review', 'burger', 'buffet', 'free', 'drink', 'second', 'cafe', 'type', 'deal', 'sandwich', 'drink', 'cake', 'sandwich', 'cream', 'toilet', 'fountain', 'stand', 'good', 'small', 'track', 'need', 'guess', 'second', 'height', 'long', 'second', 'super', 'free', 'euro', 'door', 'deal', 'euro', 'dress', 'gift', 'gift', 'store', 'love', 'start', 'help', 'work', 'hard']
# ['enjoy', 'came', 'aerosmith', 'need', 'look', 'type', 'english', 'cream', 'whilst', 'watch', 'turn', 'reason', 'took', 'long', 'return', 'term', 'avoid', 'long']
# ['pack', 'think', 'need', 'half', 'coach', 'long', 'walk', 'euro', 'coach', 'sure', 'euro', 'euro', 'drink', 'euro', 'hotdog', 'roll', 'euro', 'coke', 'kiosk', 'euro', 'offer', 'english', 'shop', 'china', 'euro', 'shirt', 'pocket', 'paint', 'look', 'hollywood', 'sign', 'need', 'look', 'bear', 'donald', 'highlight', 'went', 'float', 'superb', 'respect', 'pocket']
# ['visitor', 'school', 'peak', 'half', 'need']
# ['enjoy', 'love', 'firework']
# ['brilliant', 'clock', 'public', 'firework', 'brilliant']
# ['went', 'sister', 'took', 'travel', 'agent', 'shock', 'phone', 'help', 'transfer', 'taxi', 'extra', 'wheelchair', 'height', 'reason', 'phone', 'think', 'wheelchair', 'airport', 'fine', 'door', 'rubbish', 'decor', 'bathroom', 'window', 'lift', 'transfer', 'came', 'pick', 'hire', 'wheelchair', 'hard', 'shop', 'deposit', 'hire', 'hall', 'blue', 'letter', 'jump', 'section', 'push', 'wheelchair', 'studio', 'seat', 'wheelchair', 'railway', 'rubbish', 'section', 'wheelchair', 'lift', 'step', 'seat', 'exit', 'lift', 'shame', 'half', 'term', 'term', 'toilet', 'drive', 'wheelchair', 'shop', 'wheelchair', 'paper', 'look', 'good', 'limit', 'worker', 'door', 'exit', 'sister', 'love', 'mention']
# ['hello', 'share', 'view', 'went', 'disappoint', 'half', 'stand', 'skip', 'walk', 'quicker', 'access']
# ['level']
# ['blue', 'lagoon', 'good', 'lightyear', 'tour', 'problem', 'tour', 'jump', 'rude', 'visitor', 'rude', 'rock', 'member', 'treatment', 'euro', 'rush', 'later', 'walk', 'buffet', 'outlet', 'look', 'buffet', 'note', 'standard', 'internet', 'print', 'long', 'print', 'gate', 'print', 'pain', 'code', 'need', 'small', 'wheel', 'size', 'small', 'pack', 'wheel', 'problem', 'hopper', 'risk', 'check', 'euro', 'best', 'toilet', 'best', 'style', 'toilet', 'april', 'toilet', 'block', 'toilet', 'lake', 'smoke', 'smoke', 'left', 'self', 'long', 'period', 'effort', 'make', 'sure', 'look', 'good', 'glass', 'long', 'care', 'long', 'close', 'better', 'offer', 'site', 'second', 'free', 'discount', 'site', 'small', 'discount']
# ['look', 'english', 'sign', 'english', 'french', 'english', 'easter', 'plane', 'sure', 'think', 'felt', 'level', 'lack', 'work', 'enthusiasm', 'member', 'meet', 'greet', 'work', 'reason', 'member', 'bathroom', 'tour', 'aspect', 'think', 'good', 'best', 'make']
# ['friend', 'came', 'smaller', 'american', 'version', 'ball']
# ['friday', 'sunday', 'girl', 'month', 'fair', 'research', 'travel', 'look', 'miss', 'start', 'good', 'spot', 'worth', 'firework', 'display', 'long', 'pack', 'floor', 'display', 'better', 'display', 'offer', 'resort', 'studio', 'song', 'parent', 'love', 'offer', 'friday', 'need', 'free', 'quicker', 'taxi', 'come', 'process', 'long', 'avoid', 'rider', 'long', 'option', 'help', 'young', 'toddler', 'saturday', 'studio', 'sunday', 'smaller', 'taxi', 'minimum', 'dont', 'fact', 'mind', 'dont', 'jump', 'airport', 'taxi', 'reason', 'option', 'mcdonald', 'type', 'cheap', 'second', 'took', 'sandwich', 'order', 'head', 'fantasyland', 'good', 'toddler', 'small', 'cute', 'good', 'smile', 'face', 'studio', 'cool', 'better', 'crush', 'nemo', 'switch', 'work', 'better', 'cover', 'return']
# ['download', 'walk']
# ['school', 'come', 'later', 'good', 'railroad', 'best', 'thrill', 'island', 'come', 'drop', 'ground', 'cool', 'trick', 'stitch', 'cool', 'warm', 'love']
# ['young', 'went', 'enjoy', 'return', 'good', 'feel', 'close', 'section', 'discount', 'return', 'close', 'corner', 'studio', 'studio', 'tram', 'tour', 'corner', 'crush', 'stop', 'standard', 'fair', 'long', 'enter', 'make', 'crush', 'nemo', 'minimum', 'height', 'small', 'came', 'twilight', 'zone', 'tower', 'terror', 'heart', 'stop', 'minimum', 'height', 'option', 'limit', 'standard', 'item', 'buffet', 'style', 'recommend', 'backpack', 'drink', 'guest', 'rate', 'discount', 'recommend', 'rate', 'option', 'huge', 'transport', 'long', 'transport', 'result', 'push', 'tourist', 'twice', 'london', 'door', 'metro', 'sight', 'event', 'period', 'make', 'london', 'eurostar', 'london', 'king', 'recommend', 'king', 'walk']
# ['childhood', 'dream', 'come', 'studio', 'thank', 'rider', 'long', 'dream', 'left', 'video', 'dream', 'watch']
# ['nice', 'nice', 'stay', 'watch', 'firework', 'went', 'studio']
# ['offer', 'good', 'deal', 'wonder', 'cold', 'turn', 'forget', 'good', 'snow', 'love', 'float', 'light', 'snow', 'meet', 'push', 'decor', 'love', 'clean', 'guest', 'good', 'father', 'nice', 'drink', 'stand', 'nice', 'whilst', 'studio', 'good', 'rock', 'love', 'stay', 'father', 'turn', 'guest', 'santa', 'parent', 'santa', 'group', 'santa', 'rush', 'push', 'father', 'good', 'look', 'need', 'touch', 'sheer', 'guest', 'push', 'jump', 'fault', 'problem', 'think', 'problem', 'rude', 'american', 'watch', 'recommend', 'rope', 'half', 'best', 'view', 'ground', 'love', 'better']
# ['sign', 'wear', 'need', 'limit', 'legoland', 'better']
# ['return', 'girl', 'ball', 'fine', 'girl', 'dumbo', 'firework', 'start', 'round', 'start', 'good', 'view', 'firework', 'good', 'view', 'worth', 'walk', 'round', 'love']
# ['past', 'love', 'return', 'felt', 'member', 'spot', 'face', 'stand', 'look', 'sound', 'dress', 'heat', 'type', 'work', 'felt', 'look', 'clean', 'rubbish', 'floor', 'design', 'smoke', 'care', 'love', 'fact', 'walk', 'spot', 'moment', 'walk', 'spot', 'spot', 'recommend', 'stay', 'love', 'size', 'lightyear', 'drink', 'cheap', 'sure', 'coke', 'minimum', 'enjoy', 'love', 'left', 'feel']
# ['return']
# ['good', 'australia', 'barrier', 'offer', 'option', 'planet', 'hollywood', 'burger', 'long', 'close', 'disappoint', 'bring', 'care']
# ['think', 'better', 'clean', 'spent', 'autograph', 'worth', 'bunch', 'stay']
# ['smaller', 'today', 'close', 'moment', 'order', 'french', 'cinema', 'good', 'french', 'euro', 'cinema', 'dream']
# ['wonder', 'kingdom']
# ['took', 'april', 'good', 'deal', 'stay', 'close', 'twice', 'came', 'close', 'crush', 'enjoy', 'came', 'make', 'spot', 'make', 'sure', 'make', 'enjoy', 'studio', 'small', 'need', 'fine', 'went', 'feel', 'need', 'skip']
# ['feel', 'love', 'travel', 'make', 'swap', 'gripe', 'need', 'need']
# ['went', 'good', 'travel']
# ['french', 'english', 'brilliant', 'event', 'enjoy', 'love', 'firework', 'hard', 'work', 'parent', 'make', 'felt', 'recommend', 'return', 'outlet', 'adventureland', 'poor', 'hard', 'live', 'mood', 'snack', 'help', 'term', 'level']
# ['went', 'went', 'friday', 'hope', 'enter', 'went', 'took', 'total', 'worth', 'focus', 'fantasyland', 'carousel', 'long', 'flight', 'dumbo', 'love', 'stand', 'twice', 'stop', 'good', 'pick', 'better', 'huge', 'weekday', 'wise']
# ['better', 'good', 'firework', 'nice', 'nice', 'good']
# ['poor', 'huge', 'enter', 'door', 'limit', 'half', 'total', 'toilet', 'autograph', 'french', 'concern', 'autograph', 'turn', 'manner', 'lack', 'joke', 'matter', 'push', 'stage', 'came', 'stage', 'make', 'crush', 'hand', 'total', 'barrier', 'stop', 'crush', 'young', 'sort', 'action', 'behaviour', 'health', 'spot', 'huge', 'young', 'push', 'make', 'access', 'turn', 'rest', 'smoke', 'french', 'smoke', 'walk', 'height', 'return', 'young', 'poor', 'total']
# ['doubt', 'best', 'spot', 'love']
# ['dream', 'come', 'enjoy', 'make', 'sure', 'make', 'sure', 'forget', 'public', 'long', 'track', 'enjoy', 'autopia', 'young', 'captain', 'nemo', 'miss', 'dream']
# ['travel', 'coach', 'coach', 'travel', 'need', 'steak', 'coach', 'young', 'thought', 'board', 'meant', 'play', 'spent', 'studio', 'total', 'thrill', 'recommend', 'aerosmith', 'terror', 'tower', 'runaway', 'hint', 'work', 'round', 'relax', 'frontier', 'balloon', 'right', 'view', 'rush', 'round', 'watch', 'good', 'armageddon', 'good', 'start', 'snow', 'shop', 'stuff', 'wear', 'wonder', 'start', 'half', 'start', 'seat', 'cold', 'watch', 'view', 'stand', 'bank', 'float', 'better', 'view', 'level', 'greet', 'meet', 'right', 'english', 'recommend', 'coach', 'thrill', 'lightyear', 'planet', 'hollywood', 'recommend', 'seat', 'notch', 'french', 'rush', 'england', 'half', 'enjoy', 'good', 'wine', 'look', 'music', 'help', 'store', 'glass', 'enjoy', 'review', 'better', 'stop', 'huge', 'cash', 'cash', 'coach', 'step', 'dress', 'enjoy', 'cold', 'coach', 'took', 'view', 'coach', 'stop', 'grand', 'boat', 'tower', 'tower', 'huge', 'close', 'breath', 'long', 'souvenir', 'women', 'offer', 'paper', 'walk', 'pick', 'pocket', 'close', 'enjoy', 'sight', 'tower', 'tower', 'tower', 'light', 'light', 'return', 'england', 'passport', 'control', 'beer', 'hint', 'camera', 'card']
# ['august', 'clean', 'view', 'light', 'nice', 'worth', 'love', 'lack', 'brand', 'brand', 'gate', 'enter', 'sign', 'barrier', 'lift', 'better', 'need', 'traffic', 'help', 'question', 'answer', 'booth', 'need', 'print', 'sure', 'walk', 'travel', 'travel', 'airport', 'switch', 'travel', 'work', 'mother', 'gate', 'wheel', 'chair', 'turn', 'wheel', 'chair', 'hire', 'booth', 'meet', 'jack', 'sparrow', 'heart', 'session', 'shade', 'thought', 'track', 'worth', 'paper', 'print', 'date', 'date', 'fish', 'chip', 'shut', 'exit', 'road', 'work', 'exit', 'lane', 'exit', 'perfect', 'walk', 'sort', 'stop', 'free', 'need', 'poor', 'level']
# ['small', 'long', 'long', 'walk', 'smoke', 'smoke', 'public', 'smoke', 'design', 'smoke', 'smoke', 'rule', 'look', 'think', 'worth']
# ['feel', 'meet', 'cartoon', 'word', 'feel', 'cartoon', 'forget', 'meet']
# ['bucket', 'list', 'took', 'comfort', 'went', 'decor', 'snow', 'worth', 'smaller', 'hollywood', 'studio', 'went', 'weekday', 'disappoint', 'worth']
# ['return', 'thought', 'share', 'help', 'cover', 'recommend', 'stay', 'free', 'euro', 'access', 'orbitron', 'lightyear', 'laser', 'discoveryland', 'carousel', 'dumbo', 'fantasyland', 'meet', 'greet', 'long', 'rush', 'form', 'quieter', 'stay', 'crockett', 'ranch', 'voucher', 'cafe', 'discoveryland', 'enter', 'half', 'slot', 'treat', 'head', 'straight', 'smaller', 'went', 'switch', 'small', 'riverboat', 'forest', 'stage', 'labyrinth', 'good', 'meet', 'greet', 'think', 'look', 'long', 'took', 'half', 'standard', 'voucher', 'came', 'half', 'board', 'plaza', 'garden', 'cafe', 'love', 'buffet', 'good', 'drink', 'need', 'make', 'best', 'good', 'make', 'spectacular', 'need', 'good', 'spot', 'toilet', 'spot', 'rain', 'stand', 'road', 'good', 'push', 'good', 'snow', 'white', 'pinocchio', 'cover', 'rain', 'boat', 'nice', 'young', 'stage', 'meet', 'greet', 'long', 'forest', 'love', 'pavilion', 'stage', 'love', 'firework', 'worth', 'watch', 'band', 'stand', 'view', 'problem', 'traffic', 'shop', 'hope', 'help']
# ['took', 'wonder', 'recommend', 'hire', 'stroller', 'walk', 'meet', 'better', 'smaller', 'push', 'standard', 'look', 'face', 'meet', 'cinderella']
# ['visitor', 'love', 'sister', 'perfect', 'road', 'autograph', 'look', 'face', 'paint', 'best', 'good', 'love', 'close']
# ['august', 'guess', 'went', 'small', 'dumbo', 'tour', 'standard', 'paper', 'floor', 'block', 'toilet', 'stay', 'diner', 'diner', 'enjoy', 'think']
# ['love', 'free', 'stay', 'toilet', 'cent', 'shop', 'cent', 'stay', 'cent', 'right', 'free', 'holder', 'stay', 'free', 'need', 'cent', 'shop', 'cent', 'cent', 'stay', 'cent']
# ['help', 'stand', 'clean', 'guest', 'hint', 'turn', 'look', 'enjoy', 'care', 'rule', 'kingdom']
# ['dream', 'come', 'spent', 'studio', 'total', 'worth', 'highlight', 'kind', 'love', 'come']
# ['eurodisney', 'watch', 'girl', 'pain', 'junk', 'buffet', 'salad', 'good', 'health', 'play', 'donald', 'duck', 'rude', 'wheelchair']
# ...
# ['fault', 'firework', 'display', 'winter', 'till', 'event']
# ['april', 'better', 'opinion', 'better', 'walk', 'round', 'good', 'feel', 'american', 'effort', 'spring', 'love', 'need']
# ['young', 'love', 'stay', 'wild', 'west', 'style']
# ['friday', 'came', 'stay', 'club', 'access', 'worth', 'think', 'came', 'doubt', 'weekday', 'school']
# ['best', 'love', 'enjoy']
# ['came', 'wonder', 'close', 'level', 'thrill', 'look', 'cheap', 'good', 'cheap', 'pasta', 'soda', 'sandwich', 'snack', 'skip', 'long', 'enter', 'rider', 'disappoint', 'come']
# ['drink', 'long', 'carribean', 'concern', 'disappoint', 'good']
# ['need', 'paint', 'long', 'reason', 'option']
# ['state', 'travel', 'offer', 'small', 'frozen', 'eurodisney', 'travel', 'free', 'rest', 'case', 'crap', 'friend', 'whilst', 'think', 'travel']
# ['disappoint', 'good', 'round', 'check', 'case', 'close']
# ['live', 'japan', 'tokyo', 'euro', 'tokyo', 'tokyo', 'miss', 'walk', 'cinderella', 'tokyo', 'bear', 'miss', 'girl', 'pricey', 'good', 'skip']
# ['love', 'love', 'love', 'lazer', 'blast', 'small', 'boat', 'care', 'tourist', 'stop', 'walk', 'dream']
# ['good', 'make', 'american', 'recommend', 'america']
# ['love', 'april', 'august', 'frozen', 'watch', 'clean']
# ['come', 'dont', 'tale', 'guest', 'good', 'dont', 'didnt', 'sound', 'effect', 'action', 'rock', 'crush', 'small', 'cartoon', 'effect', 'dark', 'case', 'cool', 'feel', 'rest', 'perfect']
# ['round', 'good', 'travel', 'light', 'snack', 'pack', 'stay', 'better', 'public', 'worth', 'brilliant', 'section', 'studio']
# ['went', 'month', 'went', 'second', 'weekday', 'quieter', 'second', 'sunday', 'meet', 'long', 'young', 'better', 'love', 'tour', 'make', 'sure', 'twice', 'gate']
# ['review', 'better', 'state', 'think', 'state', 'travel', 'walk', 'half', 'snack', 'thought', 'option', 'cream', 'fountain', 'mainstreet', 'shop', 'mainstreet', 'option', 'frontierland', 'love', 'dragon', 'enjoy', 'decor', 'shop', 'smaller', 'live', 'fantasyland', 'rode', 'carousel', 'okay', 'moment', 'enjoy', 'love', 'display', 'dragon', 'labyrinth', 'close', 'treat', 'small', 'worth', 'live', 'discoveryland', 'seat', 'ground', 'recommend', 'discoveryland', 'firework', 'site', 'worth', 'decor', 'enjoy', 'decor', 'worth', 'note', 'love', 'adventureland', 'rode', 'girlfriend', 'took', 'girlfriend', 'heat', 'enjoy', 'captain', 'jack', 'recommend', 'island', 'robinson', 'half', 'discoveryland', 'phantom', 'manor', 'shop', 'option', 'decor', 'close', 'phantom', 'manor', 'display', 'cover', 'manor', 'enjoy', 'spirit', 'kiosk', 'rode', 'hope', 'help', 'enjoy', 'recommend']
# ['america', 'sure', 'review', 'advisor', 'stay', 'spent', 'resort', 'studio', 'perfect', 'access', 'meet', 'meet', 'greet', 'recommend', 'picnic', 'type', 'hyper', 'tour', 'tour', 'studio', 'miss']
# ['nice', 'kitchen', 'poor', 'super', 'soup', 'cold', 'cold', 'clean', 'pasta', 'cold', 'super', 'ball', 'hard', 'euro', 'shame']
# ['love', 'burger', 'nugget', 'chip', 'good', 'rude', 'push', 'come']
# ['feel', 'long', 'glad', 'went', 'crush']
# ['shop', 'rapunzel', 'close', 'whilst', 'light', 'start', 'second', 'disappoint']
# ['went', 'meet', 'greet', 'review', 'smoke', 'complaint', 'design', 'smoke', 'smoke', 'walk', 'smoke', 'face', 'face', 'meet', 'crush', 'meet', 'greet', 'good', 'epcot', 'think', 'dozen', 'length', 'thrill', 'long', 'look', 'wonder', 'walk', 'close', 'make', 'hope', 'thrill', 'need']
# ['took', 'metro', 'enter', 'went']
# ['clean', 'good', 'watch', 'firework', 'come']
# ['brilliant', 'firework']
# ['good', 'good', 'think']
# ['second', 'march', 'member', 'smile', 'spectacular', 'decor', 'superb', 'meet', 'good', 'disappoint', 'riverboat', 'close', 'march', 'look', 'close']
# ['comment', 'feel', 'need', 'share', 'cafe', 'poor', 'diner', 'newport', 'good', 'sure', 'worth', 'plaza', 'garden', 'newport', 'guest', 'disappoint', 'deal', 'pick', 'cendrillon', 'menu', 'stop', 'rapunzel', 'felt', 'group', 'look', 'girl']
# ['close']
# ['love', 'disappoint', 'walk', 'autograph', 'stage', 'went', 'disappoint', 'light', 'spectacular', 'feel']
# ['wonder', 'grandson', 'need', 'care', 'think', 'fountain', 'avoid', 'track', 'stay', 'access', 'good', 'avoid', 'menu', 'good', 'railway', 'good', 'relax', 'bear', 'start', 'firework', 'display', 'brilliant', 'make', 'sure', 'view', 'process', 'good', 'good', 'view', 'avoid', 'disappoint', 'grandson', 'good', 'second', 'wonderland', 'maze', 'return', 'second', 'thought', 'dumbo', 'height', 'white', 'hand', 'free']
# ['avoid', 'thought', 'eurodisney', 'disappoint', 'good', 'long', 'free', 'travel', 'spot', 'best', 'design', 'tower', 'terror', 'walk', 'studio', 'turn', 'right', 'shop', 'cinema', 'think', 'check', 'date', 'bathroom', 'avoid', 'look', 'restroom', 'gate', 'need', 'fact', 'disappoint', 'clean', 'stuff', 'nice', 'site', 'close', 'case', 'restroom', 'site', 'lack', 'power']
# ['heart', 'took', 'warm', 'love', 'case', 'rain', 'good', 'sight', 'offer', 'cover', 'went', 'watch', 'wonder', 'small', 'face', 'shop', 'friend', 'friend', 'make', 'matter', 'matter', 'live']
# ['minimum', 'stuff', 'euro', 'cream', 'come', 'hard', 'stop', 'work', 'care', 'voucher', 'skip', 'work', 'stop', 'boat', 'glad', 'euro', 'toilet', 'close', 'thought', 'american', 'left', 'thought', 'american', 'guess']
# ['went', 'left', 'drink', 'bench']
# ['poor', 'review', 'standard', 'love', 'member', 'help', 'english', 'member', 'nice', 'enjoy', 'paint', 'chip', 'light', 'trash', 'work', 'highlight']
# ['parc', 'patch', 'friday']
# ['turn', 'enjoy']
# ['nephew', 'clean', 'decor', 'guest', 'occasion', 'help', 'visitor', 'euro', 'buffet', 'joke', 'menu', 'walk', 'hotdog', 'make', 'donald', 'better']
# ['matter', 'love', 'love', 'long', 'sure', 'bargain', 'mind', 'enjoy', 'think']
# ['gripe', 'stay', 'public']
# ['make', 'parent', 'stand', 'long', 'second', 'dark', 'vader', 'long', 'feel', 'euro', 'hard', 'cold', 'euro', 'burger', 'euro', 'cold', 'junk', 'nice', 'second', 'dark', 'vader', 'euro', 'euro', 'euro']
# ['long', 'stand', 'market', 'good', 'half', 'seat', 'menu', 'fine', 'good', 'view']
# ['clean', 'toilet', 'fountain', 'drink', 'best', 'deal', 'effect', 'pick', 'meant']
# ['review', 'firework', 'start', 'close', 'trick', 'state', 'long', 'later', 'display', 'display', 'walk', 'forget', 'twice', 'huge', 'rider', 'left', 'recommend', 'rider', 'thrill', 'rude', 'shock', 'bring', 'drink', 'firework', 'display', 'close', 'phantom', 'manor', 'pace', 'rush', 'stay', 'dream', 'dream', 'order', 'stop', 'stop', 'right', 'hand', 'come', 'make', 'sure', 'window', 'display', 'come', 'dream', 'push', 'pack']
# ['stay', 'head', 'start', 'shop']
# ['lack', 'eurodisney', 'member', 'member', 'thought', 'took', 'wheel', 'shop', 'stuff', 'wheelchair', 'fact', 'look', 'sort']
# ['american', 'eurodisney', 'seat', 'seat', 'recommend', 'dumbo', 'took', 'french', 'english', 'small', 'cart', 'close']
# ['notch', 'help', 'french', 'best', 'partner', 'love']
# ['took', 'stay', 'york', 'matter', 'clean', 'matter', 'menu', 'matter', 'matter', 'matter', 'look', 'super', 'member', 'love', 'enjoy', 'long', 'meet', 'tigger']
# ['good', 'best', 'firework', 'light', 'floor', 'close', 'date', 'cheap', 'burger', 'chip', 'drink', 'thrill', 'disappoint', 'partner', 'think', 'walk', 'right', 'right', 'start']
# ['went', 'march', 'thought', 'close', 'disappoint', 'frontierland', 'french', 'came', 'close', 'took', 'went', 'woman', 'forget', 'good', 'disappoint', 'return']
# ['love', 'clean', 'bring', 'dream', 'matter', 'come']
# ['love', 'feel', 'good', 'love', 'dont', 'need', 'free', 'worth', 'stay']
# ['long', 'stay', 'complaint', 'stay', 'good', 'clean', 'english', 'meet', 'pluto', 'brilliant', 'close', 'matter', 'check', 'close', 'list', 'state', 'close', 'bring', 'snack', 'cheap', 'supermarket', 'sandwich', 'fruit', 'beer', 'wine', 'beer', 'wine', 'dessert', 'diner', 'mcdonald', 'toddler', 'drink', 'recommend', 'bring', 'shop', 'milk', 'problem', 'drink', 'didnt', 'rude', 'visitor', 'love', 'return', 'toddler', 'enjoy', 'dress', 'better', 'dress', 'bring', 'dress', 'half', 'enjoy']
# []
# ['today', 'midday', 'track', 'menu', 'offer', 'poor']
# ['return', 'total']
# ['spent', 'small', 'small', 'budget', 'stand', 'second', 'small', 'town', 'fair', 'stand', 'feel', 'hype', 'date']
# ['spent', 'good', 'look', 'review', 'came', 'comment', 'straight', 'rude', 'crew', 'member', 'nice', 'play', 'shop', 'nice', 'help', 'close', 'rude', 'walk', 'chip', 'dale', 'tigger', 'cinderella', 'pooh', 'studio', 'sure', 'right', 'mind', 'walk', 'sign', 'autograph', 'burger', 'type', 'burger', 'burger', 'sandwich', 'pizza', 'fish', 'chicken', 'lightyear', 'went', 'work', 'phantom', 'manor', 'stop', 'stroller', 'stop', 'think', 'comment', 'went', 'felt', 'need', 'review']
# ['thought', 'euro', 'think', 'need', 'smoke', 'design', 'smoke', 'spot', 'french', 'smoke', 'respect', 'care', 'chip', 'pain', 'shop', 'rule']
# ['young', 'live', 'dream']
# ['love', 'dream', 'need', 'member', 'help', 'stay', 'level', 'stunt', 'cold', 'turn', 'shop', 'fine', 'good', 'shop', 'walk', 'need', 'beer']
# ['straight', 'help', 'complaint', 'hard', 'cheap']
# ['brilliant', 'group']
# ['love', 'enjoy', 'help']
# ['love', 'good', 'thought', 'smaller', 'tower', 'smaller', 'smaller', 'disappoint', 'stay', 'took', 'took', 'love', 'enter', 'bucket', 'list', 'stay', 'view', 'small', 'close', 'phantom', 'manor', 'best', 'toad', 'hall', 'silver', 'good']
# ['good', 'travel', 'huge', 'long', 'problem', 'walk', 'hope', 'small', 'snack', 'order', 'enjoy']
# ['good', 'close', 'close', 'whilst', 'half', 'reason', 'love', 'frontier', 'close', 'half', 'close', 'hand', 'nice', 'pushchair', 'wheelchair', 'hire', 'recommend', 'stroller', 'cover', 'walk', 'option', 'nice', 'dessert', 'treat', 'voucher', 'drink', 'cream']
# ['dream', 'holder', 'round', 'relax', 'meet', 'blast', 'huge']
# ['enjoy', 'sight', 'make', 'sure', 'free', 'free', 'event', 'respect']
# ['love', 'need', 'best', 'tower', 'terror', 'hollywood', 'studio', 'smoke', 'site', 'small', 'best', 'recommend', 'america', 'better', 'need']
# ['free', 'mile', 'took', 'stay', 'took', 'rest', 'long', 'light', 'small', 'rush', 'stop', 'better', 'went', 'studio', 'souvenir']
# ['stay', 'whilst', 'good', 'result', 'stay', 'public', 'opinion']
# ['young', 'thrill', 'dark', 'drop', 'counterpart', 'state', 'tour', 'recommend', 'head', 'sure', 'wear', 'long', 'jacket', 'cold', 'occasion', 'snow', 'make']
# ['love', 'clean', 'kingdom', 'visitor', 'enjoy']
# ['small', 'enjoy', 'alot', 'long', 'need']
# ['love', 'look', 'clean']
# ['went', 'enjoy', 'cover', 'enjoy']
# ['stay', 'sequoia', 'check', 'went', 'straight', 'good', 'start', 'walk', 'long', 'smaller', 'french', 'french', 'public', 'question', 'small', 'tour', 'studio', 'poor', 'poor', 'comment', 'smoke', 'felt', 'pushchair', 'design', 'smoke', 'free', 'enjoy']
# ['euro', 'hopper', 'hollywood', 'studio', 'wednesday', 'glad', 'long', 'took', 'astro', 'pace', 'section', 'start', 'close', 'labyrinth', 'close', 'miss', 'hollywood', 'studio', 'door', 'close', 'start', 'close', 'firework', 'left', 'firework', 'avoid', 'long', 'stay', 'make', 'stop', 'light', 'return']
# ['look', 'comparison', 'small', 'cart', 'pack', 'left', 'offer', 'rude', 'order', 'track', 'went', 'left', 'feel', 'float', 'dark', 'light', 'walk', 'concept', 'forget', 'work', 'second', 'young', 'parent', 'enjoy', 'wonder', 'face', 'light']
# ['love', 'love', 'love', 'smaller', 'spent', 'better', 'kiosk', 'super', 'style', 'good', 'recommend', 'chicken', 'chip', 'soda', 'cream', 'came', 'euro', 'standard', 'thought', 'recommend', 'long', 'flight']
# ['tokyo', 'shanghai', 'left', 'smaller', 'good', 'twist', 'total', 'recommend']
# ['spent', 'felt', 'menu', 'item', 'order', 'offer', 'lack', 'menu', 'item', 'norm', 'counter', 'start', 'close', 'half', 'close', 'bite', 'firework']
# ['travel', 'long', 'size', 'bring', 'comfort', 'feet', 'mark', 'outlet']
# ['second', 'enjoy', 'spent', 'enjoy']
# ['went', 'autograph', 'autograph', 'group', 'turn', 'whilst', 'work', 'miss', 'came', 'rush', 'group', 'left', 'thank', 'childhood', 'whilst', 'close', 'small', 'shop', 'stock', 'best', 'make', 'glass', 'small', 'work', 'rest', 'best', 'mention', 'lack', 'dream', 'meet', 'month', 'hire']
# ['fantasyland', 'frontierland', 'adventureland', 'tale', 'need', 'game']
# ['kingdom', 'dragon', 'phantom', 'manor']
# ['love', 'board', 'worth', 'member', 'work', 'hard', 'team', 'step', 'play', 'phone', 'dream', 'stay', 'holder', 'stress']
# ['feel', 'heat', 'look', 'worth', 'disappoint', 'factor', 'huge', 'stick', 'wonder', 'delight', 'american']
# ['long', 'dream', 'young', 'wonder', 'need', 'stay', 'lazer', 'firework', 'display', 'worth', 'stay']
# ['partner', 'went', 'parent', 'month', 'love', 'come', 'enter', 'later', 'mind', 'track', 'left', 'pushchair', 'touch', 'month', 'love', 'work', 'euro', 'frame', 'love', 'look', 'wall', 'offer', 'receipt', 'euro', 'love', 'pricey', 'snack', 'pizza', 'planet', 'euro', 'buffet', 'salad', 'pizza', 'pasta', 'fruit', 'play', 'member', 'watch', 'seat', 'mcdonald', 'order', 'order', 'rest', 'beer', 'drive', 'planet', 'hollywood', 'gold', 'euro', 'gift', 'think', 'come', 'small', 'recommend', 'matter']
# ['group', 'friend', 'love', 'better', 'budget', 'sandwich', 'drink', 'problem']
# ['love', 'walk', 'clock', 'good', 'travel', 'rush', 'enjoy', 'love', 'wonderland', 'maze']
# ['love', 'review', 'bring', 'fair', 'think', 'love', 'watch', 'review', 'check', 'close', 'close', 'close', 'mention', 'right', 'homework', 'attempt', 'close', 'problem', 'problem', 'paint', 'rail', 'watch', 'paint', 'disappoint', 'meet', 'design', 'result', 'american', 'better', 'pavillion', 'stay', 'long', 'fall', 'fair', 'mention', 'thought', 'good', 'rate', 'small', 'visitor', 'rule', 'design', 'smoke', 'snow', 'white', 'think', 'push', 'past', 'friend', 'small', 'sign', 'push', 'phone', 'member', 'norm', 'pavillion', 'went', 'push', 'bear', 'mind', 'start', 'feet', 'stand', 'feel', 'stand', 'parent', 'need', 'left', 'need', 'rude', 'enjoy', 'rude', 'brilliant', 'sure', 'think', 'right', 'pick', 'fault', 'right', 'result', 'class', 'note', 'look', 'face', 'stop', 'long', 'come', 'worth']
# ['brilliant', 'darth', 'vader', 'went', 'start', 'went', 'good', 'credit', 'recommend', 'winter']
# ['fault', 'saturday', 'sunday', 'thursday', 'rain', 'small', 'young', 'cold', 'stand', 'dumbo', 'thrill', 'sound', 'meet', 'rapunzel', 'push', 'rapunzel', 'good', 'think', 'meet', 'right', 'manner', 'window', 'free', 'walk', 'watch', 'good', 'meet', 'greet', 'meet', 'greet', 'studio', 'make', 'miss', 'head', 'slot', 'flight', 'left', 'fair', 'grand', 'come', 'young', 'return', 'think', 'need', 'stick', 'chicken', 'stuff', 'english', 'word', 'french', 'long', 'french', 'shop', 'english', 'english', 'think', 'make', 'french', 'sight']
# ['wonder', 'toddler', 'stay', 'health', 'good', 'better', 'later']
# ['second', 'love', 'good', 'firework', 'make', 'worth', 'drink', 'small', 'small', 'worth', 'love', 'hope', 'enjoy', 'dont', 'forget']
# ['went', 'half', 'term', 'love', 'good', 'work', 'meant', 'group', 'miss', 'shock', 'whilst', 'dumbo', 'sight', 'toilet', 'need', 'matter', 'cover', 'hand', 'hand', 'toilet', 'shock', 'make', 'problem', 'woman', 'jump', 'watch', 'step', 'enjoy', 'nice', 'walk', 'donald', 'duck']
# ['thrill', 'decor', 'total', 'shock', 'love', 'spin', 'phantom', 'manor', 'tour', 'firework', 'aspect']
# ['went', 'grandson', 'grand', 'rain', 'hard', 'stop', 'small', 'limit', 'store', 'limit', 'stock', 'walk', 'stunt', 'best', 'member', 'enter', 'gate', 'gate', 'push', 'grandson', 'push', 'ground', 'woman', 'look', 'later', 'french']
# ['spent', 'cover', 'half', 'stuff', 'game', 'euro', 'tour', 'euro', 'studio', 'close', 'close', 'cover', 'studio', 'went']
# ['worth', 'clean', 'dream', 'light']
# ['past', 'good', 'partner', 'love', 'frozen', 'work', 'shorter', 'light', 'love', 'look', 'paint', 'good', 'america', 'rude', 'member', 'went', 'extra', 'close', 'gate', 'limit', 'meant', 'track', 'recommend', 'worth', 'quieter', 'shorter']
# ['problem', 'long', 'nice']
# ['team', 'process', 'rush', 'walk', 'need', 'bring', 'game', 'bear', 'need', 'outlet', 'poor', 'poor', 'poor', 'love']

# %% [markdown]
# Next, construct a term dictionary following required format of LDA module in gensim library:

# %%
import gensim.corpora as corpora

search': 183, 'smile': 184, 'boat': 185, 'dust': 186, 'event': 187, 'fuss': 188, 'sound': 189, 'forget': 190, 'option': 191, 'racer': 192, 'aladdin': 193, 'childhood': 194, 'disappoint': 195, 'felt': 196, 'honeymoon': 197, 'rush': 198, 'vibe': 199, 'clean': 200, 'live': 201, 'center': 202, 'corn': 203, 'bench': 204, 'booth': 205, 'calendar': 206, 'face': 207, 'feet': 208, 'floor': 209, 'flow': 210, 'frontier': 211, 'hope': 212, 'opinion': 213, 'planet': 214, 'post': 215, 'program': 216, 'tomorrow': 217, 'tour': 218, 'vision': 219, 'visitor': 220, 'block': 221, 'burger': 222, 'soda': 223, 'southern': 224, 'stick': 225, 'fault': 226, 'fish': 227, 'locker': 228, 'monorail': 229, 'pizza': 230, 'woman': 231, 'cold': 232, 'comfort': 233, 'wear': 234, 'wind': 235, 'resort': 236, 'public': 237, 'pace': 238, 'agent': 239, 'blast': 240, 'cover': 241, 'nemo': 242, 'nephew': 243, 'pluto': 244, 'wall': 245, 'access': 246, 'control': 247, 'display': 248, 'effort': 249, 'form': 250, 'sister': 251, 'brilliant': 252, 'round': 253, 'site': 254, 'august': 255, 'head': 256, 'whilst': 257, 'regardless': 258, 'treat': 259, 'trick': 260, 'doubt': 261, 'today': 262, 'twice': 263, 'splash': 264, 'american': 265, 'bunch': 266, 'golden': 267, 'hill': 268, 'mother': 269, 'ranch': 270, 'stage': 271, 'gift': 272, 'hire': 273, 'step': 274, 'stress': 275, 'team': 276, 'took': 277, 'chicken': 278, 'pricey': 279, 'dark': 280, 'relax': 281, 'river': 282, 'size': 283, 'tomorrowland': 284, 'weekday' ...

# %% [markdown]
# Converting `Cleaned_doc_new` into bag of word representation based on the computed dictionary `id2word`. The presentation is in (Term Index, Frequency) format.

# %%
#Bag of Word Representation
Corpus = [id2word.doc2bow(text) for text in Cleaned_doc_new]
print(Corpus[0:5])
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 2), (4, 1), (5, 1), (6, 1), (7, 1), (8, 1), (9, 1)], [(5, 1), (10, 1), (11, 1)], [(5, 1), (12, 1), (13, 1), (14, 1), (15, 1), (16, 1), (17, 1), (18, 1), (19, 1), (20, 1), (21, 1)], [(1, 1), (5, 1), (12, 1), (14, 2), (22, 1), (23, 1), (24, 1), (25, 1), (26, 1), (27, 2), (28, 2), (29, 1), (30, 1), (31, 1), (32, 1), (33, 2), (34, 1), (35, 1), (36, 2), (37, 1), (38, 1), (39, 1), (40, 1), (41, 1), (42, 1)], [(6, 1), (20, 1), (30, 1), (43, 1), (44, 1), (45, 1), (46, 1), (47, 1), (48, 1), (49, 1), (50, 1)]]

# %% [markdown]
# #Gensim LDA Model

# %%
import gensim
from gensim.models.ldamodel import LdaModel
from pprint import pprint#

#Train model using bag of word reprentation
lda_model = gensim.models.ldamodel.LdaModel(corpus=Corpus,
                                       id2word=id2word,
                                       num_topics=7,
                                       random_state=100)

#Print the Keyword in the 10 topics
pprint(lda_model.print_topics(num_words=10))
doc_lda = lda_model[Corpus]
# Out:
# [(0,
#   '0.063*"firework" + 0.056*"went" + 0.048*"stay" + 0.038*"good" + '
#   '0.032*"worth" + 0.029*"recommend" + 0.025*"love" + 0.024*"enjoy" + '
#   '0.020*"light" + 0.019*"best"'),
#  (1,
#   '0.040*"make" + 0.032*"drink" + 0.029*"need" + 0.024*"good" + 0.023*"sure" + '
#   '0.022*"bring" + 0.020*"walk" + 0.019*"french" + 0.015*"stay" + '
#   '0.015*"shop"'),
#  (2,
#   '0.145*"love" + 0.043*"dream" + 0.036*"meet" + 0.032*"come" + 0.025*"clean" '
#   '+ 0.025*"help" + 0.024*"wonder" + 0.022*"enjoy" + 0.018*"worth" + '
#   '0.017*"make"'),
#  (3,
#   '0.025*"push" + 0.024*"rude" + 0.024*"start" + 0.017*"close" + 0.016*"stand" '
#   '+ 0.014*"disappoint" + 0.014*"walk" + 0.014*"long" + 0.013*"went" + '
#   '0.013*"nice"'),
#  (4,
#   '0.052*"close" + 0.030*"good" + 0.019*"stay" + 0.016*"small" + 0.016*"walk" '
#   '+ 0.014*"went" + 0.013*"disappoint" + 0.012*"half" + 0.012*"better" + '
#   '0.012*"studio"'),
#  (5,
#   '0.059*"smoke" + 0.037*"long" + 0.036*"meet" + 0.033*"good" + 0.024*"better" '
#   '+ 0.023*"avoid" + 0.023*"enjoy" + 0.022*"miss" + 0.014*"feel" + '
#   '0.014*"greet"'),
#  (6,
#   '0.052*"euro" + 0.037*"enjoy" + 0.029*"studio" + 0.025*"long" + 0.022*"good" '
#   '+ 0.018*"small" + 0.018*"toilet" + 0.016*"went" + 0.016*"need" + '
#   '0.016*"took"')]

# %% [markdown]
# Computing coherence score

# %%
from gensim.models import CoherenceModel

# Compute Coherence Score. Note: that CoherenceModel require
# text input format (Cleaned_doc_new) instead of bag of word
coherence_model_lda = CoherenceModel(model=lda_model,
                                     texts=Cleaned_doc_new,
                                     dictionary=id2word,
                                     coherence='c_v')


coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Coherence Score:  0.7244440252522415

# %% [markdown]
# The coherence score of 0.7244 for the model with 7 topics indicates a high level of interpretability and semantic consistency among the topics. This score suggests that the topics generated by the model are well-defined and meaningful, making 7 an optimal number of topics for analyzing the review data.

# %%
#Evaluation models with topics numbers from 2 to 10
Topics = list(range(2,11,1))
coherence_scores = []
Trained_Models = []
for top in Topics:
    lda_model = gensim.models.ldamodel.LdaModel(corpus=Corpus,
                                               id2word=id2word,
                                               num_topics=top,
                                               random_state=100)
    #Keeping the trained models
    Trained_Models.append(lda_model)
    #Computing coherence score for each model
    coherence_model_lda = CoherenceModel(model=lda_model,
                                         texts=Cleaned_doc_new,
                                         dictionary=id2word,
                                         coherence='c_v')
    coherence = coherence_model_lda.get_coherence()
    #Save and print the coherence scores
    coherence_scores.append(coherence)
    print('Topic Number: {0} -- Coherence: {1}'.format(top, coherence))
# Out:
# Topic Number: 2 -- Coherence: 0.7248823689270462
# Topic Number: 3 -- Coherence: 0.7144007809946992
# Topic Number: 4 -- Coherence: 0.7135729250767753
# Topic Number: 5 -- Coherence: 0.7189570988298731
# Topic Number: 6 -- Coherence: 0.7132335046614467
# Topic Number: 7 -- Coherence: 0.7244440252522415
# Topic Number: 8 -- Coherence: 0.7204545731301549
# Topic Number: 9 -- Coherence: 0.704844249404617
# Topic Number: 10 -- Coherence: 0.7121500287774262

# %% [markdown]
# Plotting the coherence scores for the ease of interpretation. The desired topic number is the one that produce highest coherence score.

# %%
pyplot.figure(figsize=(6,4))
pyplot.plot(coherence_scores)
pyplot.xticks(range(0,len(Topics)),Topics)
pyplot.title('Coherence Score by Topic Number', fontsize=16)
pyplot.xlabel('Topic Number')
pyplot.ylabel('Coherence')
# Out:
# Text(0, 0.5, 'Coherence')

# %% [markdown]
# #The Best Model
# Extracting and analyzing the best LDA model.

# %%
import numpy
lda_model = Trained_Models[numpy.argmax(coherence_scores)]

#Show top 10 words in each topic
lda_model.show_topics(num_words=10)
# Out:
# [(0,
#   '0.047*"love" + 0.035*"good" + 0.034*"went" + 0.032*"enjoy" + 0.024*"firework" + 0.024*"stay" + 0.021*"worth" + 0.021*"long" + 0.017*"meet" + 0.016*"recommend"'),
#  (1,
#   '0.023*"close" + 0.019*"make" + 0.018*"good" + 0.017*"need" + 0.017*"walk" + 0.014*"euro" + 0.013*"long" + 0.013*"look" + 0.013*"come" + 0.011*"disappoint"')]

# %% [markdown]
# #Practical Implication
#
#
# Based on the insights from our analysis, we recommend the following actions to better support customers at theme parks:
#
# 1. Peak Times: we can enhance staffing and resource allocation during peak months (July and December) to ensure smooth operations. Moreover, we can implement virtual queueing systems that allow visitors to reserve their spot in line via a mobile app, reducing physical wait times and enabling guests to enjoy other attractions or amenities while they wait.
#
# 2. Enhance Transportation and Logistics: For visitors from the United Kingdom, focus on improving transportation services and providing clear signage and maps. Introduce a comprehensive, on-demand shuttle service within the park and to nearby hotels and transportation hubs.
#
# 3. Cultural Tailoring in Marketing: Adapt marketing and service offerings to align with local preferences. For example, emphasize regional attractions and amenities in promotional campaigns aimed at specific geographic areas. This approach enhances relevance and engagement with the target audience.
#
# 4. Customer feedback: We can continuously collect and evaluate visitor feedback to remain responsive to changing preferences and concerns. Establish real-time feedback systems to promptly address any issues that arise, ensuring a better visitor experience.
#
# 5. Interactive Family Zones: Create interactive, technology-enhanced family zones where parents and children can participate in activities together. These zones could feature AR games, interactive storytelling, and live character interactions to provide memorable family experiences.
#
# 6. Personalized Experience Platforms: Develop an app that leverages artificial intelligence to offer personalized itineraries. The app could suggest attractions, dining options, and shows based on the visitor's interests and past behavior, ensuring a tailored and engaging experience.

# %% [markdown]
# #Reference list
#
# admin (2024). Unlocking Global Markets: Multicultural Marketing Strategies. [online] Programmatic Marketing | Multicultural Marketing. Available at: https://www.isearchmarketing.com.au/unlocking-global-markets-multicultural-marketing-strategies/ [Accessed 7 Aug. 2024].
#
# Kezia Grace Jungco (2024). What Is Sentiment Analysis? Essential Guide. [online] Datamation. Available at: https://www-datamation-com.translate.goog/trends/sentiment-analysis/?_x_tr_hl=id&_x_tr_pto=rq&_x_tr_sl=en&_x_tr_tl=id [Accessed 7 Aug. 2024].
#
# Navigate (2023). How to Use Visitor Feedback as a Marketing Goldmine. [online] Navigate. Available at: https://www.navigate.agency/blog/how-to-use-visitor-feedback/ [Accessed 7 Aug. 2024].
#
# Olohijere, F. (2024). The Power of Personalizing User Experience. [online] Medium. Available at: https://uxplanet.org/the-power-of-personalizing-user-experience-a88e2f3bee29.
#
# Wikipedia Contributors (2019). Latent Dirichlet allocation. [online] Wikipedia. Available at: https://en.wikipedia.org/wiki/Latent_Dirichlet_allocation
